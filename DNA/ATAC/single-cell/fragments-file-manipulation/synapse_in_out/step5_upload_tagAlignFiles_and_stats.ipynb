# %%
# step5:
# upload the tagAlign and the stats to synpase at the same hierarchy
# make sure that the tagAlign is being gzip

# %%
# Destination folder: syn52167911
# %run synapse_utils_from_analysis.ipynb
# Out:
# Welcome, eila!

# %%
folders_to_upload = [os.path.join(os.getcwd(),"clusters",x) for x in os.listdir("./clusters/")]
print(folders_to_upload[0:4])
synapse_folder_id = "syn52167911"
# Out:
# ['/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR052DKH', '/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR397LYX', '/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR367GKP', '/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR205TUH']

# %%
# (local_folder_path, synapse_folder_id):
# %run synapse_utils_from_analysis.ipynb
for folder in folders_to_upload:
    # print("folder is {}".format(folder))
    upload_folder_to_synapse(folder,synapse_folder_id)
# Out:
# Welcome, eila!
#
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR052DKH
# create_or_get_folder: Folder 'ENCSR052DKH' already exists with ID: syn52185794
# upload_folder_to_synapse: syn_folder is syn52185794
# list_dir is ['tagAlign_ENCSR052DKH_Tuft_cell.tsv', 'ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR052DKH_Macrophage.tsv', 'tagAlign_ENCSR052DKH_T_lymphocyte.tsv', 'tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR052DKH_Tuft_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185794
# check_file_exists: file_names is ['ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR052DKH_Macrophage.tsv', 'tagAlign_ENCSR052DKH_T_lymphocyte.tsv', 'tagAlign_ENCSR052DKH_Tuft_cell.tsv', 'tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185794
# file_name tagAlign_ENCSR052DKH_Tuft_cell.tsv exists
# filename tagAlign_ENCSR052DKH_Tuft_cell.tsv already uploaded to syn_folder syn52185794
# upload_folder_to_synapse: filename is ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185794
# check_file_exists: file_names is ['ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR052DKH_Macrophage.tsv', 'tagAlign_ENCSR052DKH_T_lymphocyte.tsv', 'tagAlign_ENCSR052DKH_Tuft_cell.tsv', 'tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185794
# file_name ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185794
# upload_folder_to_synapse: filename is tagAlign_ENCSR052DKH_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185794
# check_file_exists: file_names is ['ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR052DKH_Macrophage.tsv', 'tagAlign_ENCSR052DKH_T_lymphocyte.tsv', 'tagAlign_ENCSR052DKH_Tuft_cell.tsv', 'tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185794
# file_name tagAlign_ENCSR052DKH_Macrophage.tsv exists
# filename tagAlign_ENCSR052DKH_Macrophage.tsv already uploaded to syn_folder syn52185794
# upload_folder_to_synapse: filename is tagAlign_ENCSR052DKH_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185794
# check_file_exists: file_names is ['ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR052DKH_Macrophage.tsv', 'tagAlign_ENCSR052DKH_T_lymphocyte.tsv', 'tagAlign_ENCSR052DKH_Tuft_cell.tsv', 'tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185794
# file_name tagAlign_ENCSR052DKH_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR052DKH_T_lymphocyte.tsv already uploaded to syn_folder syn52185794
# upload_folder_to_synapse: filename is tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185794
# check_file_exists: file_names is ['ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR052DKH_Macrophage.tsv', 'tagAlign_ENCSR052DKH_T_lymphocyte.tsv', 'tagAlign_ENCSR052DKH_Tuft_cell.tsv', 'tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185794
# file_name tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv already uploaded to syn_folder syn52185794
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR397LYX
# create_or_get_folder: Folder 'ENCSR397LYX' already exists with ID: syn52185795
# upload_folder_to_synapse: syn_folder is syn52185795
# list_dir is ['tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv', 'tagAlign_ENCSR397LYX_Endothelial_cell.tsv', 'ENCSR397LYX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185795
# check_file_exists: file_names is ['ENCSR397LYX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv', 'tagAlign_ENCSR397LYX_Endothelial_cell.tsv', 'tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185795
# file_name tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv already uploaded to syn_folder syn52185795
# upload_folder_to_synapse: filename is tagAlign_ENCSR397LYX_Endothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185795
# check_file_exists: file_names is ['ENCSR397LYX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv', 'tagAlign_ENCSR397LYX_Endothelial_cell.tsv', 'tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185795
# file_name tagAlign_ENCSR397LYX_Endothelial_cell.tsv exists
# filename tagAlign_ENCSR397LYX_Endothelial_cell.tsv already uploaded to syn_folder syn52185795
# upload_folder_to_synapse: filename is ENCSR397LYX_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185795
# check_file_exists: file_names is ['ENCSR397LYX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv', 'tagAlign_ENCSR397LYX_Endothelial_cell.tsv', 'tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185795
# file_name ENCSR397LYX_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR397LYX_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185795
# upload_folder_to_synapse: filename is tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185795
# check_file_exists: file_names is ['ENCSR397LYX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv', 'tagAlign_ENCSR397LYX_Endothelial_cell.tsv', 'tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185795
# file_name tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv exists
# filename tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv already uploaded to syn_folder syn52185795
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR367GKP
# create_or_get_folder: Folder 'ENCSR367GKP' already exists with ID: syn52185796
# upload_folder_to_synapse: syn_folder is syn52185796
# list_dir is ['tagAlign_ENCSR367GKP_Fibroblast.tsv', 'tagAlign_ENCSR367GKP_Schwann_cell.tsv', 'ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv', 'tagAlign_ENCSR367GKP_Macrophage.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR367GKP_Fibroblast.tsv
# check_file_exists: synapse_parent_folder_id is syn52185796
# check_file_exists: file_names is ['ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR367GKP_Fibroblast.tsv', 'tagAlign_ENCSR367GKP_Macrophage.tsv', 'tagAlign_ENCSR367GKP_Schwann_cell.tsv', 'tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185796
# file_name tagAlign_ENCSR367GKP_Fibroblast.tsv exists
# filename tagAlign_ENCSR367GKP_Fibroblast.tsv already uploaded to syn_folder syn52185796
# upload_folder_to_synapse: filename is tagAlign_ENCSR367GKP_Schwann_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185796
# check_file_exists: file_names is ['ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR367GKP_Fibroblast.tsv', 'tagAlign_ENCSR367GKP_Macrophage.tsv', 'tagAlign_ENCSR367GKP_Schwann_cell.tsv', 'tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185796
# file_name tagAlign_ENCSR367GKP_Schwann_cell.tsv exists
# filename tagAlign_ENCSR367GKP_Schwann_cell.tsv already uploaded to syn_folder syn52185796
# upload_folder_to_synapse: filename is ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185796
# check_file_exists: file_names is ['ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR367GKP_Fibroblast.tsv', 'tagAlign_ENCSR367GKP_Macrophage.tsv', 'tagAlign_ENCSR367GKP_Schwann_cell.tsv', 'tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185796
# file_name ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185796
# upload_folder_to_synapse: filename is tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185796
# check_file_exists: file_names is ['ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR367GKP_Fibroblast.tsv', 'tagAlign_ENCSR367GKP_Macrophage.tsv', 'tagAlign_ENCSR367GKP_Schwann_cell.tsv', 'tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185796
# file_name tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv already uploaded to syn_folder syn52185796
# upload_folder_to_synapse: filename is tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185796
# check_file_exists: file_names is ['ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR367GKP_Fibroblast.tsv', 'tagAlign_ENCSR367GKP_Macrophage.tsv', 'tagAlign_ENCSR367GKP_Schwann_cell.tsv', 'tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185796
# file_name tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv already uploaded to syn_folder syn52185796
# upload_folder_to_synapse: filename is tagAlign_ENCSR367GKP_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185796
# check_file_exists: file_names is ['ENCSR367GKP_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR367GKP_Fibroblast.tsv', 'tagAlign_ENCSR367GKP_Macrophage.tsv', 'tagAlign_ENCSR367GKP_Schwann_cell.tsv', 'tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185796
# file_name tagAlign_ENCSR367GKP_Macrophage.tsv exists
# filename tagAlign_ENCSR367GKP_Macrophage.tsv already uploaded to syn_folder syn52185796
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR205TUH
# create_or_get_folder: Folder 'ENCSR205TUH' already exists with ID: syn52185797
# upload_folder_to_synapse: syn_folder is syn52185797
# list_dir is ['ENCSR205TUH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.tsv', 'tagAlign_ENCSR205TUH_Schwann_cell.tsv']
# upload_folder_to_synapse: filename is ENCSR205TUH_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185797
# check_file_exists: file_names is ['ENCSR205TUH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR205TUH_Schwann_cell.tsv', 'tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185797
# file_name ENCSR205TUH_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR205TUH_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185797
# upload_folder_to_synapse: filename is tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185797
# check_file_exists: file_names is ['ENCSR205TUH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR205TUH_Schwann_cell.tsv', 'tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185797
# file_name tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.tsv already uploaded to syn_folder syn52185797
# upload_folder_to_synapse: filename is tagAlign_ENCSR205TUH_Schwann_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185797
# check_file_exists: file_names is ['ENCSR205TUH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR205TUH_Schwann_cell.tsv', 'tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185797
# file_name tagAlign_ENCSR205TUH_Schwann_cell.tsv exists
# filename tagAlign_ENCSR205TUH_Schwann_cell.tsv already uploaded to syn_folder syn52185797
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR868ZEI
# create_or_get_folder: Folder 'ENCSR868ZEI' already exists with ID: syn52185798
# upload_folder_to_synapse: syn_folder is syn52185798
# list_dir is ['tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_Mast_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_Mast_cell.tsv exists
# filename tagAlign_ENCSR868ZEI_Mast_cell.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR868ZEI_T_lymphocyte.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_Macrophage.tsv exists
# filename tagAlign_ENCSR868ZEI_Macrophage.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_Endothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_Endothelial_cell.tsv exists
# filename tagAlign_ENCSR868ZEI_Endothelial_cell.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_Schwann_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_Schwann_cell.tsv exists
# filename tagAlign_ENCSR868ZEI_Schwann_cell.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_Myofibroblast.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_Myofibroblast.tsv exists
# filename tagAlign_ENCSR868ZEI_Myofibroblast.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_Fibroblast.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_Fibroblast.tsv exists
# filename tagAlign_ENCSR868ZEI_Fibroblast.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: filename is tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185798
# check_file_exists: file_names is ['ENCSR868ZEI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR868ZEI_Endothelial_cell.tsv', 'tagAlign_ENCSR868ZEI_Fibroblast.tsv', 'tagAlign_ENCSR868ZEI_Macrophage.tsv', 'tagAlign_ENCSR868ZEI_Mast_cell.tsv', 'tagAlign_ENCSR868ZEI_Myofibroblast.tsv', 'tagAlign_ENCSR868ZEI_Schwann_cell.tsv', 'tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR868ZEI_T_lymphocyte.tsv', 'tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185798
# file_name tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv already uploaded to syn_folder syn52185798
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR506YMX
# create_or_get_folder: Folder 'ENCSR506YMX' already exists with ID: syn52185799
# upload_folder_to_synapse: syn_folder is syn52185799
# list_dir is ['tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv', 'ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv', 'tagAlign_ENCSR506YMX_Tuft_cell.tsv', 'tagAlign_ENCSR506YMX_Goblet_cell.tsv', 'tagAlign_ENCSR506YMX_T_lymphocyte.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185799
# check_file_exists: file_names is ['ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR506YMX_Goblet_cell.tsv', 'tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR506YMX_T_lymphocyte.tsv', 'tagAlign_ENCSR506YMX_Tuft_cell.tsv', 'tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185799
# file_name tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv exists
# filename tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv already uploaded to syn_folder syn52185799
# upload_folder_to_synapse: filename is ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185799
# check_file_exists: file_names is ['ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR506YMX_Goblet_cell.tsv', 'tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR506YMX_T_lymphocyte.tsv', 'tagAlign_ENCSR506YMX_Tuft_cell.tsv', 'tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185799
# file_name ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185799
# upload_folder_to_synapse: filename is tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185799
# check_file_exists: file_names is ['ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR506YMX_Goblet_cell.tsv', 'tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR506YMX_T_lymphocyte.tsv', 'tagAlign_ENCSR506YMX_Tuft_cell.tsv', 'tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185799
# file_name tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv already uploaded to syn_folder syn52185799
# upload_folder_to_synapse: filename is tagAlign_ENCSR506YMX_Tuft_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185799
# check_file_exists: file_names is ['ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR506YMX_Goblet_cell.tsv', 'tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR506YMX_T_lymphocyte.tsv', 'tagAlign_ENCSR506YMX_Tuft_cell.tsv', 'tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185799
# file_name tagAlign_ENCSR506YMX_Tuft_cell.tsv exists
# filename tagAlign_ENCSR506YMX_Tuft_cell.tsv already uploaded to syn_folder syn52185799
# upload_folder_to_synapse: filename is tagAlign_ENCSR506YMX_Goblet_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185799
# check_file_exists: file_names is ['ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR506YMX_Goblet_cell.tsv', 'tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR506YMX_T_lymphocyte.tsv', 'tagAlign_ENCSR506YMX_Tuft_cell.tsv', 'tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185799
# file_name tagAlign_ENCSR506YMX_Goblet_cell.tsv exists
# filename tagAlign_ENCSR506YMX_Goblet_cell.tsv already uploaded to syn_folder syn52185799
# upload_folder_to_synapse: filename is tagAlign_ENCSR506YMX_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185799
# check_file_exists: file_names is ['ENCSR506YMX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR506YMX_Goblet_cell.tsv', 'tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR506YMX_T_lymphocyte.tsv', 'tagAlign_ENCSR506YMX_Tuft_cell.tsv', 'tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185799
# file_name tagAlign_ENCSR506YMX_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR506YMX_T_lymphocyte.tsv already uploaded to syn_folder syn52185799
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR411MLR
# create_or_get_folder: Folder 'ENCSR411MLR' already exists with ID: syn52185800
# upload_folder_to_synapse: syn_folder is syn52185800
# list_dir is ['ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR411MLR_Macrophage.tsv', 'tagAlign_ENCSR411MLR_T_lymphocyte.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv', 'tagAlign_ENCSR411MLR_Endothelial_cell.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv']
# upload_folder_to_synapse: filename is ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185800
# check_file_exists: file_names is ['ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR411MLR_Endothelial_cell.tsv', 'tagAlign_ENCSR411MLR_Macrophage.tsv', 'tagAlign_ENCSR411MLR_T_lymphocyte.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv']. synapse_parent_folder_id is syn52185800
# file_name ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185800
# upload_folder_to_synapse: filename is tagAlign_ENCSR411MLR_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185800
# check_file_exists: file_names is ['ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR411MLR_Endothelial_cell.tsv', 'tagAlign_ENCSR411MLR_Macrophage.tsv', 'tagAlign_ENCSR411MLR_T_lymphocyte.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv']. synapse_parent_folder_id is syn52185800
# file_name tagAlign_ENCSR411MLR_Macrophage.tsv exists
# filename tagAlign_ENCSR411MLR_Macrophage.tsv already uploaded to syn_folder syn52185800
# upload_folder_to_synapse: filename is tagAlign_ENCSR411MLR_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185800
# check_file_exists: file_names is ['ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR411MLR_Endothelial_cell.tsv', 'tagAlign_ENCSR411MLR_Macrophage.tsv', 'tagAlign_ENCSR411MLR_T_lymphocyte.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv']. synapse_parent_folder_id is syn52185800
# file_name tagAlign_ENCSR411MLR_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR411MLR_T_lymphocyte.tsv already uploaded to syn_folder syn52185800
# upload_folder_to_synapse: filename is tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv
# check_file_exists: synapse_parent_folder_id is syn52185800
# check_file_exists: file_names is ['ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR411MLR_Endothelial_cell.tsv', 'tagAlign_ENCSR411MLR_Macrophage.tsv', 'tagAlign_ENCSR411MLR_T_lymphocyte.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv']. synapse_parent_folder_id is syn52185800
# file_name tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv exists
# filename tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv already uploaded to syn_folder syn52185800
# upload_folder_to_synapse: filename is tagAlign_ENCSR411MLR_Endothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185800
# check_file_exists: file_names is ['ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR411MLR_Endothelial_cell.tsv', 'tagAlign_ENCSR411MLR_Macrophage.tsv', 'tagAlign_ENCSR411MLR_T_lymphocyte.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv']. synapse_parent_folder_id is syn52185800
# file_name tagAlign_ENCSR411MLR_Endothelial_cell.tsv exists
# filename tagAlign_ENCSR411MLR_Endothelial_cell.tsv already uploaded to syn_folder syn52185800
# upload_folder_to_synapse: filename is tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv
# check_file_exists: synapse_parent_folder_id is syn52185800
# check_file_exists: file_names is ['ENCSR411MLR_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR411MLR_Endothelial_cell.tsv', 'tagAlign_ENCSR411MLR_Macrophage.tsv', 'tagAlign_ENCSR411MLR_T_lymphocyte.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv', 'tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv']. synapse_parent_folder_id is syn52185800
# file_name tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv exists
# filename tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv already uploaded to syn_folder syn52185800
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR848EID
# create_or_get_folder: Folder 'ENCSR848EID' already exists with ID: syn52185801
# upload_folder_to_synapse: syn_folder is syn52185801
# list_dir is ['tagAlign_ENCSR848EID_Gastric_chief_cell.tsv', 'ENCSR848EID_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR848EID_Macrophage.tsv', 'tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR848EID_T_lymphocyte.tsv', 'tagAlign_ENCSR848EID_Fibroblast.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR848EID_Gastric_chief_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185801
# check_file_exists: file_names is ['ENCSR848EID_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR848EID_Fibroblast.tsv', 'tagAlign_ENCSR848EID_Gastric_chief_cell.tsv', 'tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR848EID_Macrophage.tsv', 'tagAlign_ENCSR848EID_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185801
# file_name tagAlign_ENCSR848EID_Gastric_chief_cell.tsv exists
# filename tagAlign_ENCSR848EID_Gastric_chief_cell.tsv already uploaded to syn_folder syn52185801
# upload_folder_to_synapse: filename is ENCSR848EID_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185801
# check_file_exists: file_names is ['ENCSR848EID_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR848EID_Fibroblast.tsv', 'tagAlign_ENCSR848EID_Gastric_chief_cell.tsv', 'tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR848EID_Macrophage.tsv', 'tagAlign_ENCSR848EID_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185801
# file_name ENCSR848EID_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR848EID_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185801
# upload_folder_to_synapse: filename is tagAlign_ENCSR848EID_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185801
# check_file_exists: file_names is ['ENCSR848EID_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR848EID_Fibroblast.tsv', 'tagAlign_ENCSR848EID_Gastric_chief_cell.tsv', 'tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR848EID_Macrophage.tsv', 'tagAlign_ENCSR848EID_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185801
# file_name tagAlign_ENCSR848EID_Macrophage.tsv exists
# filename tagAlign_ENCSR848EID_Macrophage.tsv already uploaded to syn_folder syn52185801
# upload_folder_to_synapse: filename is tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185801
# check_file_exists: file_names is ['ENCSR848EID_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR848EID_Fibroblast.tsv', 'tagAlign_ENCSR848EID_Gastric_chief_cell.tsv', 'tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR848EID_Macrophage.tsv', 'tagAlign_ENCSR848EID_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185801
# file_name tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv exists
# filename tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv already uploaded to syn_folder syn52185801
# upload_folder_to_synapse: filename is tagAlign_ENCSR848EID_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185801
# check_file_exists: file_names is ['ENCSR848EID_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR848EID_Fibroblast.tsv', 'tagAlign_ENCSR848EID_Gastric_chief_cell.tsv', 'tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR848EID_Macrophage.tsv', 'tagAlign_ENCSR848EID_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185801
# file_name tagAlign_ENCSR848EID_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR848EID_T_lymphocyte.tsv already uploaded to syn_folder syn52185801
# upload_folder_to_synapse: filename is tagAlign_ENCSR848EID_Fibroblast.tsv
# check_file_exists: synapse_parent_folder_id is syn52185801
# check_file_exists: file_names is ['ENCSR848EID_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR848EID_Fibroblast.tsv', 'tagAlign_ENCSR848EID_Gastric_chief_cell.tsv', 'tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv', 'tagAlign_ENCSR848EID_Macrophage.tsv', 'tagAlign_ENCSR848EID_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185801
# file_name tagAlign_ENCSR848EID_Fibroblast.tsv exists
# filename tagAlign_ENCSR848EID_Fibroblast.tsv already uploaded to syn_folder syn52185801
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR660NEE
# create_or_get_folder: Folder 'ENCSR660NEE' already exists with ID: syn52185802
# upload_folder_to_synapse: syn_folder is syn52185802
# list_dir is ['tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR660NEE_Fibroblast.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name tagAlign_ENCSR660NEE_Fibroblast.tsv exists
# filename tagAlign_ENCSR660NEE_Fibroblast.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: filename is tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: filename is tagAlign_ENCSR660NEE_Mast_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name tagAlign_ENCSR660NEE_Mast_cell.tsv exists
# filename tagAlign_ENCSR660NEE_Mast_cell.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: filename is tagAlign_ENCSR660NEE_Schwann_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name tagAlign_ENCSR660NEE_Schwann_cell.tsv exists
# filename tagAlign_ENCSR660NEE_Schwann_cell.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: filename is tagAlign_ENCSR660NEE_Endothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name tagAlign_ENCSR660NEE_Endothelial_cell.tsv exists
# filename tagAlign_ENCSR660NEE_Endothelial_cell.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: filename is tagAlign_ENCSR660NEE_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name tagAlign_ENCSR660NEE_Macrophage.tsv exists
# filename tagAlign_ENCSR660NEE_Macrophage.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: filename is tagAlign_ENCSR660NEE_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name tagAlign_ENCSR660NEE_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR660NEE_T_lymphocyte.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: filename is tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: filename is ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185802
# check_file_exists: file_names is ['ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR660NEE_Endothelial_cell.tsv', 'tagAlign_ENCSR660NEE_Fibroblast.tsv', 'tagAlign_ENCSR660NEE_Macrophage.tsv', 'tagAlign_ENCSR660NEE_Mast_cell.tsv', 'tagAlign_ENCSR660NEE_Schwann_cell.tsv', 'tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR660NEE_T_lymphocyte.tsv', 'tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv']. synapse_parent_folder_id is syn52185802
# file_name ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185802
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR261TQO
# create_or_get_folder: Folder 'ENCSR261TQO' already exists with ID: syn52185803
# upload_folder_to_synapse: syn_folder is syn52185803
# list_dir is ['tagAlign_ENCSR261TQO_Endothelial_cell.tsv', 'tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv', 'tagAlign_ENCSR261TQO_Ductal_cell.tsv', 'tagAlign_ENCSR261TQO_T_lymphocyte.tsv', 'tagAlign_ENCSR261TQO_Macrophage.tsv', 'tagAlign_ENCSR261TQO_Acinar_cell.tsv', 'ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR261TQO_Endothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185803
# check_file_exists: file_names is ['ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR261TQO_Acinar_cell.tsv', 'tagAlign_ENCSR261TQO_Ductal_cell.tsv', 'tagAlign_ENCSR261TQO_Endothelial_cell.tsv', 'tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv', 'tagAlign_ENCSR261TQO_Macrophage.tsv', 'tagAlign_ENCSR261TQO_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185803
# file_name tagAlign_ENCSR261TQO_Endothelial_cell.tsv exists
# filename tagAlign_ENCSR261TQO_Endothelial_cell.tsv already uploaded to syn_folder syn52185803
# upload_folder_to_synapse: filename is tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185803
# check_file_exists: file_names is ['ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR261TQO_Acinar_cell.tsv', 'tagAlign_ENCSR261TQO_Ductal_cell.tsv', 'tagAlign_ENCSR261TQO_Endothelial_cell.tsv', 'tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv', 'tagAlign_ENCSR261TQO_Macrophage.tsv', 'tagAlign_ENCSR261TQO_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185803
# file_name tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv exists
# filename tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv already uploaded to syn_folder syn52185803
# upload_folder_to_synapse: filename is tagAlign_ENCSR261TQO_Ductal_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185803
# check_file_exists: file_names is ['ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR261TQO_Acinar_cell.tsv', 'tagAlign_ENCSR261TQO_Ductal_cell.tsv', 'tagAlign_ENCSR261TQO_Endothelial_cell.tsv', 'tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv', 'tagAlign_ENCSR261TQO_Macrophage.tsv', 'tagAlign_ENCSR261TQO_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185803
# file_name tagAlign_ENCSR261TQO_Ductal_cell.tsv exists
# filename tagAlign_ENCSR261TQO_Ductal_cell.tsv already uploaded to syn_folder syn52185803
# upload_folder_to_synapse: filename is tagAlign_ENCSR261TQO_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185803
# check_file_exists: file_names is ['ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR261TQO_Acinar_cell.tsv', 'tagAlign_ENCSR261TQO_Ductal_cell.tsv', 'tagAlign_ENCSR261TQO_Endothelial_cell.tsv', 'tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv', 'tagAlign_ENCSR261TQO_Macrophage.tsv', 'tagAlign_ENCSR261TQO_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185803
# file_name tagAlign_ENCSR261TQO_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR261TQO_T_lymphocyte.tsv already uploaded to syn_folder syn52185803
# upload_folder_to_synapse: filename is tagAlign_ENCSR261TQO_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185803
# check_file_exists: file_names is ['ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR261TQO_Acinar_cell.tsv', 'tagAlign_ENCSR261TQO_Ductal_cell.tsv', 'tagAlign_ENCSR261TQO_Endothelial_cell.tsv', 'tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv', 'tagAlign_ENCSR261TQO_Macrophage.tsv', 'tagAlign_ENCSR261TQO_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185803
# file_name tagAlign_ENCSR261TQO_Macrophage.tsv exists
# filename tagAlign_ENCSR261TQO_Macrophage.tsv already uploaded to syn_folder syn52185803
# upload_folder_to_synapse: filename is tagAlign_ENCSR261TQO_Acinar_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185803
# check_file_exists: file_names is ['ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR261TQO_Acinar_cell.tsv', 'tagAlign_ENCSR261TQO_Ductal_cell.tsv', 'tagAlign_ENCSR261TQO_Endothelial_cell.tsv', 'tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv', 'tagAlign_ENCSR261TQO_Macrophage.tsv', 'tagAlign_ENCSR261TQO_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185803
# file_name tagAlign_ENCSR261TQO_Acinar_cell.tsv exists
# filename tagAlign_ENCSR261TQO_Acinar_cell.tsv already uploaded to syn_folder syn52185803
# upload_folder_to_synapse: filename is ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185803
# check_file_exists: file_names is ['ENCSR261TQO_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR261TQO_Acinar_cell.tsv', 'tagAlign_ENCSR261TQO_Ductal_cell.tsv', 'tagAlign_ENCSR261TQO_Endothelial_cell.tsv', 'tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv', 'tagAlign_ENCSR261TQO_Macrophage.tsv', 'tagAlign_ENCSR261TQO_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185803
# ...
# check_file_exists: synapse_parent_folder_id is syn52185812
# check_file_exists: file_names is ['ENCSR474TGL_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR474TGL_Basal_epithelial_cell.tsv', 'tagAlign_ENCSR474TGL_Endothelial_cell.tsv', 'tagAlign_ENCSR474TGL_Fibroblast.tsv', 'tagAlign_ENCSR474TGL_Macrophage.tsv']. synapse_parent_folder_id is syn52185812
# file_name tagAlign_ENCSR474TGL_Basal_epithelial_cell.tsv exists
# filename tagAlign_ENCSR474TGL_Basal_epithelial_cell.tsv already uploaded to syn_folder syn52185812
# upload_folder_to_synapse: filename is tagAlign_ENCSR474TGL_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185812
# check_file_exists: file_names is ['ENCSR474TGL_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR474TGL_Basal_epithelial_cell.tsv', 'tagAlign_ENCSR474TGL_Endothelial_cell.tsv', 'tagAlign_ENCSR474TGL_Fibroblast.tsv', 'tagAlign_ENCSR474TGL_Macrophage.tsv']. synapse_parent_folder_id is syn52185812
# file_name tagAlign_ENCSR474TGL_Macrophage.tsv exists
# filename tagAlign_ENCSR474TGL_Macrophage.tsv already uploaded to syn_folder syn52185812
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR796RXX
# create_or_get_folder: Folder 'ENCSR796RXX' already exists with ID: syn52185813
# upload_folder_to_synapse: syn_folder is syn52185813
# list_dir is ['ENCSR796RXX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR796RXX_Follicular_cell.tsv', 'tagAlign_ENCSR796RXX_Fibroblast.tsv', 'tagAlign_ENCSR796RXX_Endothelial_cell.tsv']
# upload_folder_to_synapse: filename is ENCSR796RXX_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185813
# check_file_exists: file_names is ['ENCSR796RXX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR796RXX_Endothelial_cell.tsv', 'tagAlign_ENCSR796RXX_Fibroblast.tsv', 'tagAlign_ENCSR796RXX_Follicular_cell.tsv']. synapse_parent_folder_id is syn52185813
# file_name ENCSR796RXX_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR796RXX_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185813
# upload_folder_to_synapse: filename is tagAlign_ENCSR796RXX_Follicular_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185813
# check_file_exists: file_names is ['ENCSR796RXX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR796RXX_Endothelial_cell.tsv', 'tagAlign_ENCSR796RXX_Fibroblast.tsv', 'tagAlign_ENCSR796RXX_Follicular_cell.tsv']. synapse_parent_folder_id is syn52185813
# file_name tagAlign_ENCSR796RXX_Follicular_cell.tsv exists
# filename tagAlign_ENCSR796RXX_Follicular_cell.tsv already uploaded to syn_folder syn52185813
# upload_folder_to_synapse: filename is tagAlign_ENCSR796RXX_Fibroblast.tsv
# check_file_exists: synapse_parent_folder_id is syn52185813
# check_file_exists: file_names is ['ENCSR796RXX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR796RXX_Endothelial_cell.tsv', 'tagAlign_ENCSR796RXX_Fibroblast.tsv', 'tagAlign_ENCSR796RXX_Follicular_cell.tsv']. synapse_parent_folder_id is syn52185813
# file_name tagAlign_ENCSR796RXX_Fibroblast.tsv exists
# filename tagAlign_ENCSR796RXX_Fibroblast.tsv already uploaded to syn_folder syn52185813
# upload_folder_to_synapse: filename is tagAlign_ENCSR796RXX_Endothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185813
# check_file_exists: file_names is ['ENCSR796RXX_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR796RXX_Endothelial_cell.tsv', 'tagAlign_ENCSR796RXX_Fibroblast.tsv', 'tagAlign_ENCSR796RXX_Follicular_cell.tsv']. synapse_parent_folder_id is syn52185813
# file_name tagAlign_ENCSR796RXX_Endothelial_cell.tsv exists
# filename tagAlign_ENCSR796RXX_Endothelial_cell.tsv already uploaded to syn_folder syn52185813
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR538FPK
# create_or_get_folder: Folder 'ENCSR538FPK' already exists with ID: syn52185814
# upload_folder_to_synapse: syn_folder is syn52185814
# list_dir is ['ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR538FPK_Fibroblast.tsv', 'tagAlign_ENCSR538FPK_Endothelial_cell.tsv', 'tagAlign_ENCSR538FPK_T_lymphocyte.tsv', 'tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR538FPK_Macrophage.tsv', 'tagAlign_ENCSR538FPK_Cardiomyocyte.tsv']
# upload_folder_to_synapse: filename is ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185814
# check_file_exists: file_names is ['ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR538FPK_Cardiomyocyte.tsv', 'tagAlign_ENCSR538FPK_Endothelial_cell.tsv', 'tagAlign_ENCSR538FPK_Fibroblast.tsv', 'tagAlign_ENCSR538FPK_Macrophage.tsv', 'tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR538FPK_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185814
# file_name ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185814
# upload_folder_to_synapse: filename is tagAlign_ENCSR538FPK_Fibroblast.tsv
# check_file_exists: synapse_parent_folder_id is syn52185814
# check_file_exists: file_names is ['ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR538FPK_Cardiomyocyte.tsv', 'tagAlign_ENCSR538FPK_Endothelial_cell.tsv', 'tagAlign_ENCSR538FPK_Fibroblast.tsv', 'tagAlign_ENCSR538FPK_Macrophage.tsv', 'tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR538FPK_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185814
# file_name tagAlign_ENCSR538FPK_Fibroblast.tsv exists
# filename tagAlign_ENCSR538FPK_Fibroblast.tsv already uploaded to syn_folder syn52185814
# upload_folder_to_synapse: filename is tagAlign_ENCSR538FPK_Endothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185814
# check_file_exists: file_names is ['ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR538FPK_Cardiomyocyte.tsv', 'tagAlign_ENCSR538FPK_Endothelial_cell.tsv', 'tagAlign_ENCSR538FPK_Fibroblast.tsv', 'tagAlign_ENCSR538FPK_Macrophage.tsv', 'tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR538FPK_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185814
# file_name tagAlign_ENCSR538FPK_Endothelial_cell.tsv exists
# filename tagAlign_ENCSR538FPK_Endothelial_cell.tsv already uploaded to syn_folder syn52185814
# upload_folder_to_synapse: filename is tagAlign_ENCSR538FPK_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185814
# check_file_exists: file_names is ['ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR538FPK_Cardiomyocyte.tsv', 'tagAlign_ENCSR538FPK_Endothelial_cell.tsv', 'tagAlign_ENCSR538FPK_Fibroblast.tsv', 'tagAlign_ENCSR538FPK_Macrophage.tsv', 'tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR538FPK_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185814
# file_name tagAlign_ENCSR538FPK_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR538FPK_T_lymphocyte.tsv already uploaded to syn_folder syn52185814
# upload_folder_to_synapse: filename is tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185814
# check_file_exists: file_names is ['ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR538FPK_Cardiomyocyte.tsv', 'tagAlign_ENCSR538FPK_Endothelial_cell.tsv', 'tagAlign_ENCSR538FPK_Fibroblast.tsv', 'tagAlign_ENCSR538FPK_Macrophage.tsv', 'tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR538FPK_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185814
# file_name tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv exists
# filename tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv already uploaded to syn_folder syn52185814
# upload_folder_to_synapse: filename is tagAlign_ENCSR538FPK_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185814
# check_file_exists: file_names is ['ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR538FPK_Cardiomyocyte.tsv', 'tagAlign_ENCSR538FPK_Endothelial_cell.tsv', 'tagAlign_ENCSR538FPK_Fibroblast.tsv', 'tagAlign_ENCSR538FPK_Macrophage.tsv', 'tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR538FPK_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185814
# file_name tagAlign_ENCSR538FPK_Macrophage.tsv exists
# filename tagAlign_ENCSR538FPK_Macrophage.tsv already uploaded to syn_folder syn52185814
# upload_folder_to_synapse: filename is tagAlign_ENCSR538FPK_Cardiomyocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185814
# check_file_exists: file_names is ['ENCSR538FPK_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR538FPK_Cardiomyocyte.tsv', 'tagAlign_ENCSR538FPK_Endothelial_cell.tsv', 'tagAlign_ENCSR538FPK_Fibroblast.tsv', 'tagAlign_ENCSR538FPK_Macrophage.tsv', 'tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv', 'tagAlign_ENCSR538FPK_T_lymphocyte.tsv']. synapse_parent_folder_id is syn52185814
# file_name tagAlign_ENCSR538FPK_Cardiomyocyte.tsv exists
# filename tagAlign_ENCSR538FPK_Cardiomyocyte.tsv already uploaded to syn_folder syn52185814
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR718WGE
# create_or_get_folder: Folder 'ENCSR718WGE' already exists with ID: syn52185815
# upload_folder_to_synapse: syn_folder is syn52185815
# list_dir is ['tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv', 'tagAlign_ENCSR718WGE_Macrophage.tsv', 'tagAlign_ENCSR718WGE_Endothelial_cell.tsv', 'tagAlign_ENCSR718WGE_T_lymphocyte.tsv', 'ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185815
# check_file_exists: file_names is ['ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR718WGE_Endothelial_cell.tsv', 'tagAlign_ENCSR718WGE_Macrophage.tsv', 'tagAlign_ENCSR718WGE_T_lymphocyte.tsv', 'tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv']. synapse_parent_folder_id is syn52185815
# file_name tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv exists
# filename tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv already uploaded to syn_folder syn52185815
# upload_folder_to_synapse: filename is tagAlign_ENCSR718WGE_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185815
# check_file_exists: file_names is ['ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR718WGE_Endothelial_cell.tsv', 'tagAlign_ENCSR718WGE_Macrophage.tsv', 'tagAlign_ENCSR718WGE_T_lymphocyte.tsv', 'tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv']. synapse_parent_folder_id is syn52185815
# file_name tagAlign_ENCSR718WGE_Macrophage.tsv exists
# filename tagAlign_ENCSR718WGE_Macrophage.tsv already uploaded to syn_folder syn52185815
# upload_folder_to_synapse: filename is tagAlign_ENCSR718WGE_Endothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185815
# check_file_exists: file_names is ['ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR718WGE_Endothelial_cell.tsv', 'tagAlign_ENCSR718WGE_Macrophage.tsv', 'tagAlign_ENCSR718WGE_T_lymphocyte.tsv', 'tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv']. synapse_parent_folder_id is syn52185815
# file_name tagAlign_ENCSR718WGE_Endothelial_cell.tsv exists
# filename tagAlign_ENCSR718WGE_Endothelial_cell.tsv already uploaded to syn_folder syn52185815
# upload_folder_to_synapse: filename is tagAlign_ENCSR718WGE_T_lymphocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185815
# check_file_exists: file_names is ['ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR718WGE_Endothelial_cell.tsv', 'tagAlign_ENCSR718WGE_Macrophage.tsv', 'tagAlign_ENCSR718WGE_T_lymphocyte.tsv', 'tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv']. synapse_parent_folder_id is syn52185815
# file_name tagAlign_ENCSR718WGE_T_lymphocyte.tsv exists
# filename tagAlign_ENCSR718WGE_T_lymphocyte.tsv already uploaded to syn_folder syn52185815
# upload_folder_to_synapse: filename is ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185815
# check_file_exists: file_names is ['ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR718WGE_Endothelial_cell.tsv', 'tagAlign_ENCSR718WGE_Macrophage.tsv', 'tagAlign_ENCSR718WGE_T_lymphocyte.tsv', 'tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv']. synapse_parent_folder_id is syn52185815
# file_name ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR718WGE_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185815
# upload_folder_to_synapse: local_folder_path is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR776EOI
# create_or_get_folder: Folder 'ENCSR776EOI' already exists with ID: syn52185816
# upload_folder_to_synapse: syn_folder is syn52185816
# list_dir is ['tagAlign_ENCSR776EOI_Fibroblast.tsv', 'tagAlign_ENCSR776EOI_Macrophage.tsv', 'tagAlign_ENCSR776EOI_Cardiomyocyte.tsv', 'tagAlign_ENCSR776EOI_Mesothelial_cell.tsv', 'ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv']
# upload_folder_to_synapse: filename is tagAlign_ENCSR776EOI_Fibroblast.tsv
# check_file_exists: synapse_parent_folder_id is syn52185816
# check_file_exists: file_names is ['ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR776EOI_Cardiomyocyte.tsv', 'tagAlign_ENCSR776EOI_Fibroblast.tsv', 'tagAlign_ENCSR776EOI_Macrophage.tsv', 'tagAlign_ENCSR776EOI_Mesothelial_cell.tsv']. synapse_parent_folder_id is syn52185816
# file_name tagAlign_ENCSR776EOI_Fibroblast.tsv exists
# filename tagAlign_ENCSR776EOI_Fibroblast.tsv already uploaded to syn_folder syn52185816
# upload_folder_to_synapse: filename is tagAlign_ENCSR776EOI_Macrophage.tsv
# check_file_exists: synapse_parent_folder_id is syn52185816
# check_file_exists: file_names is ['ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR776EOI_Cardiomyocyte.tsv', 'tagAlign_ENCSR776EOI_Fibroblast.tsv', 'tagAlign_ENCSR776EOI_Macrophage.tsv', 'tagAlign_ENCSR776EOI_Mesothelial_cell.tsv']. synapse_parent_folder_id is syn52185816
# file_name tagAlign_ENCSR776EOI_Macrophage.tsv exists
# filename tagAlign_ENCSR776EOI_Macrophage.tsv already uploaded to syn_folder syn52185816
# upload_folder_to_synapse: filename is tagAlign_ENCSR776EOI_Cardiomyocyte.tsv
# check_file_exists: synapse_parent_folder_id is syn52185816
# check_file_exists: file_names is ['ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR776EOI_Cardiomyocyte.tsv', 'tagAlign_ENCSR776EOI_Fibroblast.tsv', 'tagAlign_ENCSR776EOI_Macrophage.tsv', 'tagAlign_ENCSR776EOI_Mesothelial_cell.tsv']. synapse_parent_folder_id is syn52185816
# file_name tagAlign_ENCSR776EOI_Cardiomyocyte.tsv exists
# filename tagAlign_ENCSR776EOI_Cardiomyocyte.tsv already uploaded to syn_folder syn52185816
# upload_folder_to_synapse: filename is tagAlign_ENCSR776EOI_Mesothelial_cell.tsv
# check_file_exists: synapse_parent_folder_id is syn52185816
# check_file_exists: file_names is ['ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR776EOI_Cardiomyocyte.tsv', 'tagAlign_ENCSR776EOI_Fibroblast.tsv', 'tagAlign_ENCSR776EOI_Macrophage.tsv', 'tagAlign_ENCSR776EOI_Mesothelial_cell.tsv']. synapse_parent_folder_id is syn52185816
# file_name tagAlign_ENCSR776EOI_Mesothelial_cell.tsv exists
# filename tagAlign_ENCSR776EOI_Mesothelial_cell.tsv already uploaded to syn_folder syn52185816
# upload_folder_to_synapse: filename is ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv
# check_file_exists: synapse_parent_folder_id is syn52185816
# check_file_exists: file_names is ['ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR776EOI_Cardiomyocyte.tsv', 'tagAlign_ENCSR776EOI_Fibroblast.tsv', 'tagAlign_ENCSR776EOI_Macrophage.tsv', 'tagAlign_ENCSR776EOI_Mesothelial_cell.tsv']. synapse_parent_folder_id is syn52185816
# file_name ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv exists
# filename ENCSR776EOI_stats_tagAlign_cellTypes_file.tsv already uploaded to syn_folder syn52185816

# %%
# synapse_folder_id

# %%
# list_dir = ['tagAlign_ENCSR052DKH_Tuft_cell.tsv', 'ENCSR052DKH_stats_tagAlign_cellTypes_file.tsv', 'tagAlign_ENCSR052DKH_Macrophage.tsv', '.ipynb_checkpoints', 'tagAlign_ENCSR052DKH_T_lymphocyte.tsv', 'tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv']

# list_dir = [x for x list_dir if "ipynb" not in x]
# list_dir
