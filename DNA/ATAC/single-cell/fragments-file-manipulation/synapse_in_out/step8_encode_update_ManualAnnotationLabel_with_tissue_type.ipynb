# %%
# %run tsv_files_utils_from_analysis.ipynb

# %%
encode_annotation_df = read_tsv_file_no_index("./sc_coordination_spreadsheet.xlsx-datasets.tsv")
encode_annotation_df.head(2)
# Out:
#     Unnamed: 0 organism    assay type   assay multiome series  \
# 0  ENCSR322HGX   mouse   10x multiome  scATAC     ENCSR008NTI
# 1          NaN   mouse   10x multiome   snRNA             NaN
#
#   tissue abbreviation                                      tissue name donor  \
# 0                 GAST   B6CastF1 PND14 3x female # 1-3 gastroc muscle   NaN
# 1                 GAST   B6CastF1 PND14 3x female # 1-3 gastroc muscle   NaN
#
#   disease/health status production lab primary analysist secondary analysist  \
# 0               healthy         Snyder       Liz Rebboah                 NaN
# 1               healthy         Snyder       Liz Rebboah                 NaN
#
#   peer reviewer status (ETA for peer-review)  \
# 0        Wenpin                         Done
# 1        Wenpin                         Done
#
#                                      Marker list URL  \
# 0                                                NaN
# 1  https://drive.google.com/file/d/1IyeaGZxpqO-Qa...
#
#                                      Reference atlas  \
# 0  https://www.synapse.org/#!Synapse:syn21676145/...
# 1  https://www.synapse.org/#!Synapse:syn21676145/...
#
#                               Github link Unnamed: 17
# 0  https://github.com/erebboah/enc4_mouse         NaN
# 1  https://github.com/erebboah/enc4_mouse         NaN

# %%
encode_annotation_df.columns
encode_annotation_df.rename(columns={"Unnamed: 0": "encode_id"}, inplace=True)

# %%
encode_annotation_df.head(2)
# Out:
#      encode_id organism    assay type   assay multiome series  \
# 0  ENCSR322HGX   mouse   10x multiome  scATAC     ENCSR008NTI
# 1          NaN   mouse   10x multiome   snRNA             NaN
#
#   tissue abbreviation                                      tissue name donor  \
# 0                 GAST   B6CastF1 PND14 3x female # 1-3 gastroc muscle   NaN
# 1                 GAST   B6CastF1 PND14 3x female # 1-3 gastroc muscle   NaN
#
#   disease/health status production lab primary analysist secondary analysist  \
# 0               healthy         Snyder       Liz Rebboah                 NaN
# 1               healthy         Snyder       Liz Rebboah                 NaN
#
#   peer reviewer status (ETA for peer-review)  \
# 0        Wenpin                         Done
# 1        Wenpin                         Done
#
#                                      Marker list URL  \
# 0                                                NaN
# 1  https://drive.google.com/file/d/1IyeaGZxpqO-Qa...
#
#                                      Reference atlas  \
# 0  https://www.synapse.org/#!Synapse:syn21676145/...
# 1  https://www.synapse.org/#!Synapse:syn21676145/...
#
#                               Github link Unnamed: 17
# 0  https://github.com/erebboah/enc4_mouse         NaN
# 1  https://github.com/erebboah/enc4_mouse         NaN

# %%
# !pwd
# Out:
# /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out

# %%
# load all the files with annotation that were generated
files_to_update = !ls ./clusters/ENC*/*_ClusterMetadata.tsv
files_to_update = list(files_to_update)

# for last encode dataset
# files_to_update = ['./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv']
files_to_update 
# /Users/eilaarich-landkof/Documents/Code_Stanford/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out
# Out:
# ['./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv']

# %%
# we are looking at the following columns: "encode_id" and "tissue name"
for f in files_to_update:
  print(f)
  read_file_to_update_df = read_tsv_file(f)
  print("read_file_to_update_df before adding header")
  print(read_file_to_update_df.head(2))
  # check if the column name available 
  if "TissueName" in read_file_to_update_df.columns:
    print("File {} was already updated. Moving to the next file".format(f))
    continue # make sure that we are not repeating files
  position_to_insert = read_file_to_update_df.columns.get_loc("ManualAnnotationLabel") + 1
  read_file_to_update_df = add_empty_column_at_position(read_file_to_update_df, "TissueName", position_to_insert)
#   read_file_to_update_df = add_empty_column(read_file_to_update_df, "TissueName")
  print("read_file_to_update_df after adding header")
  print(read_file_to_update_df.head(2))
  for index, row in read_file_to_update_df.iterrows():
    print("Index:", index)
    print("Row data:", row)
    print("CellClusterID is:",row['CellClusterID'])
    encode_id = row['CellClusterID'].split("_")[0]
    print("encode_id: ",encode_id)
    ManualAnnotationLabel = row['ManualAnnotationLabel']
    print("ManualAnnotationLabel: ",ManualAnnotationLabel)
#     # read the relevant row from ENCODE
    matching_row = encode_annotation_df.loc[encode_annotation_df['encode_id'] == encode_id]
    tissue_name = matching_row.iloc[0]['tissue name']
    print("Tissue Name:", tissue_name)
    read_file_to_update_df.at[index, 'TissueName'] = tissue_name
    print("read_file_to_update_df.at[index, 'TissueName'] is: ",read_file_to_update_df.at[index, 'TissueName'])
    
    
    output_file_path = f  # Replace this with the actual file path you want to save to
    read_file_to_update_df.to_csv(output_file_path, sep='\t', index=False)
    print("File {} was updated".format(f))
    print("-------------------")
# Out:
# ./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv
# read_file_to_update_df before adding header
#                         tagAlignFile CellClusterID ManualAnnotationLabel  \
# 0  ENCSR618WVK_Cluster5.tsv.tagAlign      Cluster5               T_cells
# 1  ENCSR618WVK_Cluster2.tsv.tagAlign      Cluster2           Fibroblasts
#
#    nCells MeanRNAUMIsPerCell  MeanATACFragmentsPerCell
# 0     163                 ()                      5486
# 1     632                 ()                      8898
# read_file_to_update_df after adding header
#                         tagAlignFile CellClusterID ManualAnnotationLabel  \
# 0  ENCSR618WVK_Cluster5.tsv.tagAlign      Cluster5               T_cells
# 1  ENCSR618WVK_Cluster2.tsv.tagAlign      Cluster2           Fibroblasts
#
#   TissueName  nCells MeanRNAUMIsPerCell  MeanATACFragmentsPerCell
# 0                163                 ()                      5486
# 1                632                 ()                      8898
# Index: 0
# Row data: tagAlignFile                ENCSR618WVK_Cluster5.tsv.tagAlign
# CellClusterID                                        Cluster5
# ManualAnnotationLabel                                 T_cells
# TissueName
# nCells                                                    163
# MeanRNAUMIsPerCell                                         ()
# MeanATACFragmentsPerCell                                 5486
# Name: 0, dtype: object
# CellClusterID is: Cluster5
# encode_id:  Cluster5
# ManualAnnotationLabel:  T_cells
# Tissue Name: Left lobe of liver
# read_file_to_update_df.at[index, 'TissueName'] is:  Left lobe of liver
# File ./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv was updated
# -------------------
# Index: 1
# Row data: tagAlignFile                ENCSR618WVK_Cluster2.tsv.tagAlign
# CellClusterID                                        Cluster2
# ManualAnnotationLabel                             Fibroblasts
# TissueName
# nCells                                                    632
# MeanRNAUMIsPerCell                                         ()
# MeanATACFragmentsPerCell                                 8898
# Name: 1, dtype: object
# CellClusterID is: Cluster2
# encode_id:  Cluster2
# ManualAnnotationLabel:  Fibroblasts
# Tissue Name: Left lobe of liver
# read_file_to_update_df.at[index, 'TissueName'] is:  Left lobe of liver
# File ./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv was updated
# -------------------
# Index: 2
# Row data: tagAlignFile                ENCSR618WVK_Cluster3.tsv.tagAlign
# CellClusterID                                        Cluster3
# ManualAnnotationLabel                             Hepatocytes
# TissueName
# nCells                                                   8480
# MeanRNAUMIsPerCell                                         ()
# MeanATACFragmentsPerCell                                 8488
# Name: 2, dtype: object
# CellClusterID is: Cluster3
# encode_id:  Cluster3
# ManualAnnotationLabel:  Hepatocytes
# Tissue Name: Left lobe of liver
# read_file_to_update_df.at[index, 'TissueName'] is:  Left lobe of liver
# File ./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv was updated
# -------------------
# Index: 3
# Row data: tagAlignFile                ENCSR618WVK_Cluster4.tsv.tagAlign
# CellClusterID                                        Cluster4
# ManualAnnotationLabel                             Macrophages
# TissueName
# nCells                                                    407
# MeanRNAUMIsPerCell                                         ()
# MeanATACFragmentsPerCell                                 6656
# Name: 3, dtype: object
# CellClusterID is: Cluster4
# encode_id:  Cluster4
# ManualAnnotationLabel:  Macrophages
# Tissue Name: Left lobe of liver
# read_file_to_update_df.at[index, 'TissueName'] is:  Left lobe of liver
# File ./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv was updated
# -------------------
# Index: 4
# Row data: tagAlignFile                ENCSR618WVK_Cluster1.tsv.tagAlign
# CellClusterID                                        Cluster1
# ManualAnnotationLabel                       Endothelial_cells
# TissueName
# nCells                                                    899
# MeanRNAUMIsPerCell                                         ()
# MeanATACFragmentsPerCell                                 4566
# Name: 4, dtype: object
# CellClusterID is: Cluster1
# encode_id:  Cluster1
# ManualAnnotationLabel:  Endothelial_cells
# Tissue Name: Left lobe of liver
# read_file_to_update_df.at[index, 'TissueName'] is:  Left lobe of liver
# File ./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv was updated
# -------------------
# Index: 5
# Row data: tagAlignFile                ENCSR618WVK_Cluster0.tsv.tagAlign
# CellClusterID                                        Cluster0
# ManualAnnotationLabel                          Cholangiocytes
# TissueName
# nCells                                                    598
# MeanRNAUMIsPerCell                                         ()
# MeanATACFragmentsPerCell                                 7541
# Name: 5, dtype: object
# CellClusterID is: Cluster0
# encode_id:  Cluster0
# ManualAnnotationLabel:  Cholangiocytes
# Tissue Name: Left lobe of liver
# read_file_to_update_df.at[index, 'TissueName'] is:  Left lobe of liver
# File ./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv was updated
# -------------------

# %%
read_file_to_update_df
# Out:
#                         tagAlignFile CellClusterID ManualAnnotationLabel  \
# 0  ENCSR618WVK_Cluster5.tsv.tagAlign      Cluster5               T_cells
# 1  ENCSR618WVK_Cluster2.tsv.tagAlign      Cluster2           Fibroblasts
# 2  ENCSR618WVK_Cluster3.tsv.tagAlign      Cluster3           Hepatocytes
# 3  ENCSR618WVK_Cluster4.tsv.tagAlign      Cluster4           Macrophages
# 4  ENCSR618WVK_Cluster1.tsv.tagAlign      Cluster1     Endothelial_cells
# 5  ENCSR618WVK_Cluster0.tsv.tagAlign      Cluster0        Cholangiocytes
#
#            TissueName  nCells MeanRNAUMIsPerCell  MeanATACFragmentsPerCell
# 0  Left lobe of liver     163                 ()                      5486
# 1  Left lobe of liver     632                 ()                      8898
# 2  Left lobe of liver    8480                 ()                      8488
# 3  Left lobe of liver     407                 ()                      6656
# 4  Left lobe of liver     899                 ()                      4566
# 5  Left lobe of liver     598                 ()                      7541

# %%
"TissueName" in read_file_to_update_df.columns
# Out:
# True

# %%
# !ls ./clusters/*/*
# Out:
# ./clusters/ENCSR023FME/ENCSR023FME_ClusterMetadata.tsv
# ./clusters/ENCSR023FME/NA_ENCSR023FME_cluster_id_annotation_map.tsv
# ./clusters/ENCSR023FME/tagAlign_ENCSR023FME_Basal_epithelial_cell.tsv
# ./clusters/ENCSR023FME/tagAlign_ENCSR023FME_Endothelial_cell.tsv
# ./clusters/ENCSR023FME/tagAlign_ENCSR023FME_Fibroblast.tsv
# ./clusters/ENCSR023FME/tagAlign_ENCSR023FME_Type_I_skeletal_myocyte.tsv
# ./clusters/ENCSR052DKH/ENCSR052DKH_ClusterMetadata.tsv
# ./clusters/ENCSR052DKH/tagAlign_ENCSR052DKH_Macrophage.tsv
# ./clusters/ENCSR052DKH/tagAlign_ENCSR052DKH_T_lymphocyte.tsv
# ./clusters/ENCSR052DKH/tagAlign_ENCSR052DKH_Tuft_cell.tsv
# ./clusters/ENCSR052DKH/tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR181XXQ/ENCSR181XXQ_ClusterMetadata.tsv
# ./clusters/ENCSR181XXQ/tagAlign_ENCSR181XXQ_Adipocyte.tsv
# ./clusters/ENCSR181XXQ/tagAlign_ENCSR181XXQ_Endothelial_cell.tsv
# ./clusters/ENCSR181XXQ/tagAlign_ENCSR181XXQ_Mesothelial_cell.tsv
# ./clusters/ENCSR181XXQ/tagAlign_ENCSR181XXQ_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR205TUH/ENCSR205TUH_ClusterMetadata.tsv
# ./clusters/ENCSR205TUH/tagAlign_ENCSR205TUH_Schwann_cell.tsv
# ./clusters/ENCSR205TUH/tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR261TQO/ENCSR261TQO_ClusterMetadata.tsv
# ./clusters/ENCSR261TQO/tagAlign_ENCSR261TQO_Acinar_cell.tsv
# ./clusters/ENCSR261TQO/tagAlign_ENCSR261TQO_Ductal_cell.tsv
# ./clusters/ENCSR261TQO/tagAlign_ENCSR261TQO_Endothelial_cell.tsv
# ./clusters/ENCSR261TQO/tagAlign_ENCSR261TQO_Enteroendocrine_cell.tsv
# ./clusters/ENCSR261TQO/tagAlign_ENCSR261TQO_Macrophage.tsv
# ./clusters/ENCSR261TQO/tagAlign_ENCSR261TQO_T_lymphocyte.tsv
# ./clusters/ENCSR302CMX/ENCSR302CMX_ClusterMetadata.tsv
# ./clusters/ENCSR302CMX/tagAlign_ENCSR302CMX_Endothelial_cell.tsv
# ./clusters/ENCSR302CMX/tagAlign_ENCSR302CMX_Fibroblast.tsv
# ./clusters/ENCSR302CMX/tagAlign_ENCSR302CMX_Smooth_muscle_cell.tsv
# ./clusters/ENCSR302CMX/tagAlign_ENCSR302CMX_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR367GKP/ENCSR367GKP_ClusterMetadata.tsv
# ./clusters/ENCSR367GKP/tagAlign_ENCSR367GKP_Fibroblast.tsv
# ./clusters/ENCSR367GKP/tagAlign_ENCSR367GKP_Macrophage.tsv
# ./clusters/ENCSR367GKP/tagAlign_ENCSR367GKP_Schwann_cell.tsv
# ./clusters/ENCSR367GKP/tagAlign_ENCSR367GKP_Smooth_muscle_cell.tsv
# ./clusters/ENCSR367GKP/tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR397LYX/ENCSR397LYX_ClusterMetadata.tsv
# ./clusters/ENCSR397LYX/tagAlign_ENCSR397LYX_Basal_epithelial_cell.tsv
# ./clusters/ENCSR397LYX/tagAlign_ENCSR397LYX_Endothelial_cell.tsv
# ./clusters/ENCSR397LYX/tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR411MLR/ENCSR411MLR_ClusterMetadata.tsv
# ./clusters/ENCSR411MLR/tagAlign_ENCSR411MLR_Endothelial_cell.tsv
# ./clusters/ENCSR411MLR/tagAlign_ENCSR411MLR_Macrophage.tsv
# ./clusters/ENCSR411MLR/tagAlign_ENCSR411MLR_T_lymphocyte.tsv
# ./clusters/ENCSR411MLR/tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.tsv
# ./clusters/ENCSR411MLR/tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.tsv
# ./clusters/ENCSR453TVZ/ENCSR453TVZ_ClusterMetadata.tsv
# ./clusters/ENCSR453TVZ/tagAlign_ENCSR453TVZ_Basal_epithelial_cell.1.tsv
# ./clusters/ENCSR453TVZ/tagAlign_ENCSR453TVZ_Basal_epithelial_cell.2.tsv
# ./clusters/ENCSR453TVZ/tagAlign_ENCSR453TVZ_Basal_epithelial_cell.3.tsv
# ./clusters/ENCSR453TVZ/tagAlign_ENCSR453TVZ_T_lymphocyte.tsv
# ./clusters/ENCSR455CVZ/ENCSR455CVZ_ClusterMetadata.tsv
# ./clusters/ENCSR455CVZ/tagAlign_ENCSR455CVZ_Endothelial_cell.tsv
# ./clusters/ENCSR455CVZ/tagAlign_ENCSR455CVZ_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR474TGL/ENCSR474TGL_ClusterMetadata.tsv
# ./clusters/ENCSR474TGL/tagAlign_ENCSR474TGL_Basal_epithelial_cell.tsv
# ./clusters/ENCSR474TGL/tagAlign_ENCSR474TGL_Endothelial_cell.tsv
# ./clusters/ENCSR474TGL/tagAlign_ENCSR474TGL_Fibroblast.tsv
# ./clusters/ENCSR474TGL/tagAlign_ENCSR474TGL_Macrophage.tsv
# ./clusters/ENCSR506YMX/ENCSR506YMX_ClusterMetadata.tsv
# ./clusters/ENCSR506YMX/tagAlign_ENCSR506YMX_Goblet_cell.tsv
# ./clusters/ENCSR506YMX/tagAlign_ENCSR506YMX_Luminal_epithelial_cell.tsv
# ./clusters/ENCSR506YMX/tagAlign_ENCSR506YMX_T_lymphocyte.tsv
# ./clusters/ENCSR506YMX/tagAlign_ENCSR506YMX_Tuft_cell.tsv
# ./clusters/ENCSR506YMX/tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR538FPK/ENCSR538FPK_ClusterMetadata.tsv
# ./clusters/ENCSR538FPK/tagAlign_ENCSR538FPK_Cardiomyocyte.tsv
# ./clusters/ENCSR538FPK/tagAlign_ENCSR538FPK_Endothelial_cell.tsv
# ./clusters/ENCSR538FPK/tagAlign_ENCSR538FPK_Fibroblast.tsv
# ./clusters/ENCSR538FPK/tagAlign_ENCSR538FPK_Macrophage.tsv
# ./clusters/ENCSR538FPK/tagAlign_ENCSR538FPK_Smooth_muscle_cell.tsv
# ./clusters/ENCSR538FPK/tagAlign_ENCSR538FPK_T_lymphocyte.tsv
# ./clusters/ENCSR618WVK/ENCSR618WVK_Cluster0.tsv.tagAlign
# ./clusters/ENCSR618WVK/ENCSR618WVK_Cluster1.tsv.tagAlign
# ./clusters/ENCSR618WVK/ENCSR618WVK_Cluster2.tsv.tagAlign
# ./clusters/ENCSR618WVK/ENCSR618WVK_Cluster3.tsv.tagAlign
# ./clusters/ENCSR618WVK/ENCSR618WVK_Cluster4.tsv.tagAlign
# ./clusters/ENCSR618WVK/ENCSR618WVK_Cluster5.tsv.tagAlign
# ./clusters/ENCSR618WVK/ENCSR618WVK_ClusterMetadata.tsv
# ./clusters/ENCSR618WVK/ENCSR618WVK_cluster_id_annotation_map.tsv
# ./clusters/ENCSR660NEE/ENCSR660NEE_Cluster0.tsv.tagAlign
# ./clusters/ENCSR660NEE/ENCSR660NEE_Cluster1.tsv.tagAlign
# ./clusters/ENCSR660NEE/ENCSR660NEE_Cluster2.tsv.tagAlign
# ./clusters/ENCSR660NEE/ENCSR660NEE_Cluster3.tsv.tagAlign
# ./clusters/ENCSR660NEE/ENCSR660NEE_Cluster4.tsv.tagAlign
# ./clusters/ENCSR660NEE/ENCSR660NEE_Cluster5.tsv.tagAlign
# ./clusters/ENCSR660NEE/ENCSR660NEE_Cluster6.tsv.tagAlign
# ./clusters/ENCSR660NEE/ENCSR660NEE_Cluster7.tsv.tagAlign
# ./clusters/ENCSR660NEE/ENCSR660NEE_ClusterMetadata.tsv
# ./clusters/ENCSR660NEE/ENCSR660NEE_cluster_id_annotation_map.tsv
# ./clusters/ENCSR660NEE/tagAlign_ENCSR660NEE_Endothelial_cell.tsv
# ./clusters/ENCSR660NEE/tagAlign_ENCSR660NEE_Fibroblast.tsv
# ./clusters/ENCSR660NEE/tagAlign_ENCSR660NEE_Macrophage.tsv
# ./clusters/ENCSR660NEE/tagAlign_ENCSR660NEE_Mast_cell.tsv
# ./clusters/ENCSR660NEE/tagAlign_ENCSR660NEE_Schwann_cell.tsv
# ./clusters/ENCSR660NEE/tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv
# ./clusters/ENCSR660NEE/tagAlign_ENCSR660NEE_T_lymphocyte.tsv
# ./clusters/ENCSR660NEE/tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR718WGE/ENCSR718WGE_ClusterMetadata.tsv
# ./clusters/ENCSR718WGE/tagAlign_ENCSR718WGE_Endothelial_cell.tsv
# ./clusters/ENCSR718WGE/tagAlign_ENCSR718WGE_Macrophage.tsv
# ./clusters/ENCSR718WGE/tagAlign_ENCSR718WGE_T_lymphocyte.tsv
# ./clusters/ENCSR718WGE/tagAlign_ENCSR718WGE_Type_II_pneumocyte.tsv
# ./clusters/ENCSR776EOI/ENCSR776EOI_ClusterMetadata.tsv
# ./clusters/ENCSR776EOI/tagAlign_ENCSR776EOI_Cardiomyocyte.tsv
# ./clusters/ENCSR776EOI/tagAlign_ENCSR776EOI_Fibroblast.tsv
# ./clusters/ENCSR776EOI/tagAlign_ENCSR776EOI_Macrophage.tsv
# ./clusters/ENCSR776EOI/tagAlign_ENCSR776EOI_Mesothelial_cell.tsv
# ./clusters/ENCSR796RXX/ENCSR796RXX_ClusterMetadata.tsv
# ./clusters/ENCSR796RXX/tagAlign_ENCSR796RXX_Endothelial_cell.tsv
# ./clusters/ENCSR796RXX/tagAlign_ENCSR796RXX_Fibroblast.tsv
# ./clusters/ENCSR796RXX/tagAlign_ENCSR796RXX_Follicular_cell.tsv
# ./clusters/ENCSR822GXQ/ENCSR822GXQ_ClusterMetadata.tsv
# ./clusters/ENCSR822GXQ/tagAlign_ENCSR822GXQ_Basal_epithelial_cell.tsv
# ./clusters/ENCSR822GXQ/tagAlign_ENCSR822GXQ_Endothelial_cell.tsv
# ./clusters/ENCSR822GXQ/tagAlign_ENCSR822GXQ_Fibroblast.tsv
# ./clusters/ENCSR822GXQ/tagAlign_ENCSR822GXQ_Macrophage.tsv
# ./clusters/ENCSR822GXQ/tagAlign_ENCSR822GXQ_T_lymphocyte.tsv
# ./clusters/ENCSR822GXQ/tagAlign_ENCSR822GXQ_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR845QFX/ENCSR845QFX_ClusterMetadata.tsv
# ./clusters/ENCSR845QFX/NA_ENCSR845QFX_cluster_id_annotation_map.tsv
# ./clusters/ENCSR845QFX/tagAlign_ENCSR845QFX_Endothelial_cell.tsv
# ./clusters/ENCSR845QFX/tagAlign_ENCSR845QFX_Fibroblast.tsv
# ./clusters/ENCSR845QFX/tagAlign_ENCSR845QFX_Luminal_epithelial_cell.1.tsv
# ./clusters/ENCSR845QFX/tagAlign_ENCSR845QFX_Luminal_epithelial_cell.2.tsv
# ./clusters/ENCSR845QFX/tagAlign_ENCSR845QFX_Luminal_epithelial_cell.3.tsv
# ./clusters/ENCSR845QFX/tagAlign_ENCSR845QFX_Vascular_smooth_muscle_cell.tsv
# ./clusters/ENCSR848EID/ENCSR848EID_ClusterMetadata.tsv
# ./clusters/ENCSR848EID/tagAlign_ENCSR848EID_Fibroblast.tsv
# ./clusters/ENCSR848EID/tagAlign_ENCSR848EID_Gastric_chief_cell.tsv
# ./clusters/ENCSR848EID/tagAlign_ENCSR848EID_Luminal_epithelial_cell.tsv
# ./clusters/ENCSR848EID/tagAlign_ENCSR848EID_Macrophage.tsv
# ./clusters/ENCSR848EID/tagAlign_ENCSR848EID_T_lymphocyte.tsv
# ./clusters/ENCSR868ZEI/ENCSR868ZEI_ClusterMetadata.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_Endothelial_cell.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_Fibroblast.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_Macrophage.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_Mast_cell.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_Myofibroblast.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_Schwann_cell.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_Smooth_muscle_cell.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_T_lymphocyte.tsv
# ./clusters/ENCSR868ZEI/tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.tsv
#
# ./clusters/ENCSR023FME/sort_tagAlign_ENCSR023FME_Basal_epithelial_cell:
# tagAlign_ENCSR023FME_Basal_epithelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR023FME_Basal_epithelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR023FME/sort_tagAlign_ENCSR023FME_Endothelial_cell:
# tagAlign_ENCSR023FME_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR023FME_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR023FME/sort_tagAlign_ENCSR023FME_Fibroblast:
# tagAlign_ENCSR023FME_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR023FME_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR023FME/sort_tagAlign_ENCSR023FME_Type_I_skeletal_myocyte:
# tagAlign_ENCSR023FME_Type_I_skeletal_myocyte.sorted.tagAlign.gz
# tagAlign_ENCSR023FME_Type_I_skeletal_myocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR052DKH/sort_tagAlign_ENCSR052DKH_Macrophage:
# tagAlign_ENCSR052DKH_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR052DKH_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR052DKH/sort_tagAlign_ENCSR052DKH_T_lymphocyte:
# tagAlign_ENCSR052DKH_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR052DKH_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR052DKH/sort_tagAlign_ENCSR052DKH_Tuft_cell:
# tagAlign_ENCSR052DKH_Tuft_cell.sorted.tagAlign.gz
# tagAlign_ENCSR052DKH_Tuft_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR052DKH/sort_tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR052DKH_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR181XXQ/sort_tagAlign_ENCSR181XXQ_Adipocyte:
# tagAlign_ENCSR181XXQ_Adipocyte.sorted.tagAlign.gz
# tagAlign_ENCSR181XXQ_Adipocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR181XXQ/sort_tagAlign_ENCSR181XXQ_Endothelial_cell:
# tagAlign_ENCSR181XXQ_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR181XXQ_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR181XXQ/sort_tagAlign_ENCSR181XXQ_Mesothelial_cell:
# tagAlign_ENCSR181XXQ_Mesothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR181XXQ_Mesothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR181XXQ/sort_tagAlign_ENCSR181XXQ_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR181XXQ_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR181XXQ_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR205TUH/sort_tagAlign_ENCSR205TUH_Schwann_cell:
# tagAlign_ENCSR205TUH_Schwann_cell.sorted.tagAlign.gz
# tagAlign_ENCSR205TUH_Schwann_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR205TUH/sort_tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR205TUH_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR261TQO/sort_tagAlign_ENCSR261TQO_Acinar_cell:
# tagAlign_ENCSR261TQO_Acinar_cell.sorted.tagAlign.gz
# tagAlign_ENCSR261TQO_Acinar_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR261TQO/sort_tagAlign_ENCSR261TQO_Ductal_cell:
# tagAlign_ENCSR261TQO_Ductal_cell.sorted.tagAlign.gz
# tagAlign_ENCSR261TQO_Ductal_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR261TQO/sort_tagAlign_ENCSR261TQO_Endothelial_cell:
# tagAlign_ENCSR261TQO_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR261TQO_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR261TQO/sort_tagAlign_ENCSR261TQO_Enteroendocrine_cell:
# tagAlign_ENCSR261TQO_Enteroendocrine_cell.sorted.tagAlign.gz
# tagAlign_ENCSR261TQO_Enteroendocrine_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR261TQO/sort_tagAlign_ENCSR261TQO_Macrophage:
# tagAlign_ENCSR261TQO_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR261TQO_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR261TQO/sort_tagAlign_ENCSR261TQO_T_lymphocyte:
# tagAlign_ENCSR261TQO_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR261TQO_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR302CMX/sort_tagAlign_ENCSR302CMX_Endothelial_cell:
# tagAlign_ENCSR302CMX_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR302CMX_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR302CMX/sort_tagAlign_ENCSR302CMX_Fibroblast:
# tagAlign_ENCSR302CMX_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR302CMX_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR302CMX/sort_tagAlign_ENCSR302CMX_Smooth_muscle_cell:
# tagAlign_ENCSR302CMX_Smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR302CMX_Smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR302CMX/sort_tagAlign_ENCSR302CMX_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR302CMX_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR302CMX_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR367GKP/sort_tagAlign_ENCSR367GKP_Fibroblast:
# tagAlign_ENCSR367GKP_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR367GKP_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR367GKP/sort_tagAlign_ENCSR367GKP_Macrophage:
# tagAlign_ENCSR367GKP_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR367GKP_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR367GKP/sort_tagAlign_ENCSR367GKP_Schwann_cell:
# tagAlign_ENCSR367GKP_Schwann_cell.sorted.tagAlign.gz
# tagAlign_ENCSR367GKP_Schwann_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR367GKP/sort_tagAlign_ENCSR367GKP_Smooth_muscle_cell:
# tagAlign_ENCSR367GKP_Smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR367GKP_Smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR367GKP/sort_tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR367GKP_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR397LYX/sort_tagAlign_ENCSR397LYX_Basal_epithelial_cell:
# tagAlign_ENCSR397LYX_Basal_epithelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR397LYX_Basal_epithelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR397LYX/sort_tagAlign_ENCSR397LYX_Endothelial_cell:
# tagAlign_ENCSR397LYX_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR397LYX_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR397LYX/sort_tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR397LYX_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR411MLR/sort_tagAlign_ENCSR411MLR_Endothelial_cell:
# tagAlign_ENCSR411MLR_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR411MLR_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR411MLR/sort_tagAlign_ENCSR411MLR_Macrophage:
# tagAlign_ENCSR411MLR_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR411MLR_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR411MLR/sort_tagAlign_ENCSR411MLR_T_lymphocyte:
# tagAlign_ENCSR411MLR_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR411MLR_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR411MLR/sort_tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1:
# tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.sorted.tagAlign.gz
# tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.1.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR411MLR/sort_tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2:
# tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.sorted.tagAlign.gz
# tagAlign_ENCSR411MLR_Vascular_smooth_muscle_cell.2.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR453TVZ/sort_tagAlign_ENCSR453TVZ_Basal_epithelial_cell.1:
# tagAlign_ENCSR453TVZ_Basal_epithelial_cell.1.sorted.tagAlign.gz
# tagAlign_ENCSR453TVZ_Basal_epithelial_cell.1.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR453TVZ/sort_tagAlign_ENCSR453TVZ_Basal_epithelial_cell.2:
# tagAlign_ENCSR453TVZ_Basal_epithelial_cell.2.sorted.tagAlign.gz
# tagAlign_ENCSR453TVZ_Basal_epithelial_cell.2.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR453TVZ/sort_tagAlign_ENCSR453TVZ_Basal_epithelial_cell.3:
# tagAlign_ENCSR453TVZ_Basal_epithelial_cell.3.sorted.tagAlign.gz
# tagAlign_ENCSR453TVZ_Basal_epithelial_cell.3.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR453TVZ/sort_tagAlign_ENCSR453TVZ_T_lymphocyte:
# tagAlign_ENCSR453TVZ_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR453TVZ_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR455CVZ/sort_tagAlign_ENCSR455CVZ_Endothelial_cell:
# tagAlign_ENCSR455CVZ_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR455CVZ_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR455CVZ/sort_tagAlign_ENCSR455CVZ_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR455CVZ_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR455CVZ_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR474TGL/sort_tagAlign_ENCSR474TGL_Basal_epithelial_cell:
# tagAlign_ENCSR474TGL_Basal_epithelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR474TGL_Basal_epithelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR474TGL/sort_tagAlign_ENCSR474TGL_Endothelial_cell:
# tagAlign_ENCSR474TGL_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR474TGL_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR474TGL/sort_tagAlign_ENCSR474TGL_Fibroblast:
# tagAlign_ENCSR474TGL_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR474TGL_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR474TGL/sort_tagAlign_ENCSR474TGL_Macrophage:
# tagAlign_ENCSR474TGL_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR474TGL_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR506YMX/sort_tagAlign_ENCSR506YMX_Goblet_cell:
# tagAlign_ENCSR506YMX_Goblet_cell.sorted.tagAlign.gz
# tagAlign_ENCSR506YMX_Goblet_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR506YMX/sort_tagAlign_ENCSR506YMX_Luminal_epithelial_cell:
# tagAlign_ENCSR506YMX_Luminal_epithelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR506YMX_Luminal_epithelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR506YMX/sort_tagAlign_ENCSR506YMX_T_lymphocyte:
# tagAlign_ENCSR506YMX_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR506YMX_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR506YMX/sort_tagAlign_ENCSR506YMX_Tuft_cell:
# tagAlign_ENCSR506YMX_Tuft_cell.sorted.tagAlign.gz
# tagAlign_ENCSR506YMX_Tuft_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR506YMX/sort_tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR506YMX_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR538FPK/sort_tagAlign_ENCSR538FPK_Cardiomyocyte:
# tagAlign_ENCSR538FPK_Cardiomyocyte.sorted.tagAlign.gz
# tagAlign_ENCSR538FPK_Cardiomyocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR538FPK/sort_tagAlign_ENCSR538FPK_Endothelial_cell:
# tagAlign_ENCSR538FPK_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR538FPK_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR538FPK/sort_tagAlign_ENCSR538FPK_Fibroblast:
# tagAlign_ENCSR538FPK_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR538FPK_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR538FPK/sort_tagAlign_ENCSR538FPK_Macrophage:
# tagAlign_ENCSR538FPK_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR538FPK_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR538FPK/sort_tagAlign_ENCSR538FPK_Smooth_muscle_cell:
# tagAlign_ENCSR538FPK_Smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR538FPK_Smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR538FPK/sort_tagAlign_ENCSR538FPK_T_lymphocyte:
# tagAlign_ENCSR538FPK_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR538FPK_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR618WVK/sort_ENCSR618WVK_Cluster0:
# ENCSR618WVK_Cluster0.sorted.tagAlign.gz
# ENCSR618WVK_Cluster0.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR618WVK/sort_ENCSR618WVK_Cluster1:
# ENCSR618WVK_Cluster1.sorted.tagAlign.gz
# ENCSR618WVK_Cluster1.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR618WVK/sort_ENCSR618WVK_Cluster2:
# ENCSR618WVK_Cluster2.sorted.tagAlign.gz
# ENCSR618WVK_Cluster2.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR618WVK/sort_ENCSR618WVK_Cluster3:
# ENCSR618WVK_Cluster3.sorted.tagAlign.gz
# ENCSR618WVK_Cluster3.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR618WVK/sort_ENCSR618WVK_Cluster4:
# ENCSR618WVK_Cluster4.sorted.tagAlign.gz
# ENCSR618WVK_Cluster4.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR618WVK/sort_ENCSR618WVK_Cluster5:
# ENCSR618WVK_Cluster5.sorted.tagAlign.gz
# ENCSR618WVK_Cluster5.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR660NEE/sort_tagAlign_ENCSR660NEE_Endothelial_cell:
# tagAlign_ENCSR660NEE_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR660NEE_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR660NEE/sort_tagAlign_ENCSR660NEE_Fibroblast:
# tagAlign_ENCSR660NEE_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR660NEE_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR660NEE/sort_tagAlign_ENCSR660NEE_Macrophage:
# tagAlign_ENCSR660NEE_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR660NEE_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR660NEE/sort_tagAlign_ENCSR660NEE_Mast_cell:
# tagAlign_ENCSR660NEE_Mast_cell.sorted.tagAlign.gz
# tagAlign_ENCSR660NEE_Mast_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR660NEE/sort_tagAlign_ENCSR660NEE_Schwann_cell:
# tagAlign_ENCSR660NEE_Schwann_cell.sorted.tagAlign.gz
# tagAlign_ENCSR660NEE_Schwann_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR660NEE/sort_tagAlign_ENCSR660NEE_Smooth_muscle_cell:
# tagAlign_ENCSR660NEE_Smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR660NEE_Smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR660NEE/sort_tagAlign_ENCSR660NEE_T_lymphocyte:
# tagAlign_ENCSR660NEE_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR660NEE_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR660NEE/sort_tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR660NEE_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR718WGE/sort_tagAlign_ENCSR718WGE_Endothelial_cell:
# tagAlign_ENCSR718WGE_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR718WGE_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR718WGE/sort_tagAlign_ENCSR718WGE_Macrophage:
# tagAlign_ENCSR718WGE_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR718WGE_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR718WGE/sort_tagAlign_ENCSR718WGE_T_lymphocyte:
# tagAlign_ENCSR718WGE_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR718WGE_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR718WGE/sort_tagAlign_ENCSR718WGE_Type_II_pneumocyte:
# tagAlign_ENCSR718WGE_Type_II_pneumocyte.sorted.tagAlign.gz
# tagAlign_ENCSR718WGE_Type_II_pneumocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR776EOI/sort_tagAlign_ENCSR776EOI_Cardiomyocyte:
# tagAlign_ENCSR776EOI_Cardiomyocyte.sorted.tagAlign.gz
# tagAlign_ENCSR776EOI_Cardiomyocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR776EOI/sort_tagAlign_ENCSR776EOI_Fibroblast:
# tagAlign_ENCSR776EOI_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR776EOI_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR776EOI/sort_tagAlign_ENCSR776EOI_Macrophage:
# tagAlign_ENCSR776EOI_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR776EOI_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR776EOI/sort_tagAlign_ENCSR776EOI_Mesothelial_cell:
# tagAlign_ENCSR776EOI_Mesothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR776EOI_Mesothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR796RXX/sort_tagAlign_ENCSR796RXX_Endothelial_cell:
# tagAlign_ENCSR796RXX_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR796RXX_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR796RXX/sort_tagAlign_ENCSR796RXX_Fibroblast:
# tagAlign_ENCSR796RXX_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR796RXX_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR796RXX/sort_tagAlign_ENCSR796RXX_Follicular_cell:
# tagAlign_ENCSR796RXX_Follicular_cell.sorted.tagAlign.gz
# tagAlign_ENCSR796RXX_Follicular_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR822GXQ/sort_tagAlign_ENCSR822GXQ_Basal_epithelial_cell:
# tagAlign_ENCSR822GXQ_Basal_epithelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR822GXQ_Basal_epithelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR822GXQ/sort_tagAlign_ENCSR822GXQ_Endothelial_cell:
# tagAlign_ENCSR822GXQ_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR822GXQ_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR822GXQ/sort_tagAlign_ENCSR822GXQ_Fibroblast:
# tagAlign_ENCSR822GXQ_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR822GXQ_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR822GXQ/sort_tagAlign_ENCSR822GXQ_Macrophage:
# tagAlign_ENCSR822GXQ_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR822GXQ_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR822GXQ/sort_tagAlign_ENCSR822GXQ_T_lymphocyte:
# tagAlign_ENCSR822GXQ_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR822GXQ_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR822GXQ/sort_tagAlign_ENCSR822GXQ_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR822GXQ_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR822GXQ_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR845QFX/sort_tagAlign_ENCSR845QFX_Endothelial_cell:
# tagAlign_ENCSR845QFX_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR845QFX_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR845QFX/sort_tagAlign_ENCSR845QFX_Fibroblast:
# tagAlign_ENCSR845QFX_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR845QFX_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR845QFX/sort_tagAlign_ENCSR845QFX_Luminal_epithelial_cell.1:
# tagAlign_ENCSR845QFX_Luminal_epithelial_cell.1.sorted.tagAlign.gz
# tagAlign_ENCSR845QFX_Luminal_epithelial_cell.1.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR845QFX/sort_tagAlign_ENCSR845QFX_Luminal_epithelial_cell.2:
# tagAlign_ENCSR845QFX_Luminal_epithelial_cell.2.sorted.tagAlign.gz
# tagAlign_ENCSR845QFX_Luminal_epithelial_cell.2.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR845QFX/sort_tagAlign_ENCSR845QFX_Luminal_epithelial_cell.3:
# tagAlign_ENCSR845QFX_Luminal_epithelial_cell.3.sorted.tagAlign.gz
# tagAlign_ENCSR845QFX_Luminal_epithelial_cell.3.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR845QFX/sort_tagAlign_ENCSR845QFX_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR845QFX_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR845QFX_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR848EID/sort_tagAlign_ENCSR848EID_Fibroblast:
# tagAlign_ENCSR848EID_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR848EID_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR848EID/sort_tagAlign_ENCSR848EID_Gastric_chief_cell:
# tagAlign_ENCSR848EID_Gastric_chief_cell.sorted.tagAlign.gz
# tagAlign_ENCSR848EID_Gastric_chief_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR848EID/sort_tagAlign_ENCSR848EID_Luminal_epithelial_cell:
# tagAlign_ENCSR848EID_Luminal_epithelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR848EID_Luminal_epithelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR848EID/sort_tagAlign_ENCSR848EID_Macrophage:
# tagAlign_ENCSR848EID_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR848EID_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR848EID/sort_tagAlign_ENCSR848EID_T_lymphocyte:
# tagAlign_ENCSR848EID_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR848EID_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_Endothelial_cell:
# tagAlign_ENCSR868ZEI_Endothelial_cell.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_Endothelial_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_Fibroblast:
# tagAlign_ENCSR868ZEI_Fibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_Fibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_Macrophage:
# tagAlign_ENCSR868ZEI_Macrophage.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_Macrophage.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_Mast_cell:
# tagAlign_ENCSR868ZEI_Mast_cell.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_Mast_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_Myofibroblast:
# tagAlign_ENCSR868ZEI_Myofibroblast.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_Myofibroblast.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_Schwann_cell:
# tagAlign_ENCSR868ZEI_Schwann_cell.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_Schwann_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_Smooth_muscle_cell:
# tagAlign_ENCSR868ZEI_Smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_Smooth_muscle_cell.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_T_lymphocyte:
# tagAlign_ENCSR868ZEI_T_lymphocyte.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_T_lymphocyte.sorted.tagAlign.gz.tbi
#
# ./clusters/ENCSR868ZEI/sort_tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell:
# tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.sorted.tagAlign.gz
# tagAlign_ENCSR868ZEI_Vascular_smooth_muscle_cell.sorted.tagAlign.gz.tbi
