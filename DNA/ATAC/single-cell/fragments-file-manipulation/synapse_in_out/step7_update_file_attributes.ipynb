# %%
# step 7 - update files attributes

# %%
# %run synapse_utils_from_analysis.ipynb
# Out:
# Welcome, eila!

# %%
# %run synapse_utils_from_analysis.ipynb
files_dict_to_update = list_files_in_folder('syn52167911')
# Out:
# Welcome, eila!

# %%
type(files_dict_to_update)
# Out:
# dict

# %%
"tagAlign_ENCSR023FME_Basal_epithelial_cell.tsv".split("tagAlign_")[1].split(".tsv")[0] + "_CellClusterAssignment.tsv"
# Out:
# 'ENCSR023FME_Basal_epithelial_cell_CellClusterAssignment.tsv'

# %%
# %run synapse_utils_from_analysis.ipynb
# Iterate over all items in the dictionary
for key, value in files_dict_to_update.items():
    print(f"Key: {key}, Value: {value}")
    if ("tagAlign_") in value:
        new_file_name = value.split("tagAlign_")[1].split(".tsv")[0] + "_CellClusterAssignment.tsv"
        attribute_name = "tag_align"
        attribute_value = "tag_align"
        rename_file_and_add_attribute(key, new_file_name, attribute_name, attribute_value)
    else:
        print("!!!!file name is {}. nothing to update".format(value))
# Out:
# Welcome, eila!
#
# Key: syn52187744, Value: ENCSR023FME_ClusterMetadata.tsv
# !!!!file name is ENCSR023FME_ClusterMetadata.tsv. nothing to update
# Key: syn52188865, Value: tagAlign_ENCSR023FME_Basal_epithelial_cell.tsv
# rename tagAlign_ENCSR023FME_Basal_epithelial_cell.tsv to ENCSR023FME_Basal_epithelial_cell_CellClusterAssignment.tsv
# new file entity is File: ENCSR023FME_Basal_epithelial_cell_CellClusterAssignment.tsv (syn52188865)
#   md5=b5e932b1e676d3eec593ec33a03401fa
#   fileSize=1608486992
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/clusters/ENCSR023FME
#   files=['tagAlign_ENCSR023FME_Basal_epithelial_cell.tsv']
# ...
