# %%
# %run tsv_files_utils_from_analysis.ipynb

# %%
encode_annotation_df = read_tsv_file_no_index("./sc_coordination_spreadsheet.xlsx-datasets.tsv")
encode_annotation_df.head(2)
# Out:
#     Unnamed: 0 organism    assay type   assay multiome series  \
# 0  ENCSR322HGX   mouse   10x multiome  scATAC     ENCSR008NTI
# 1          NaN   mouse   10x multiome   snRNA             NaN
#
#   tissue abbreviation                                      tissue name donor  \
# 0                 GAST   B6CastF1 PND14 3x female # 1-3 gastroc muscle   NaN
# 1                 GAST   B6CastF1 PND14 3x female # 1-3 gastroc muscle   NaN
#
#   disease/health status production lab primary analysist secondary analysist  \
# 0               healthy         Snyder       Liz Rebboah                 NaN
# 1               healthy         Snyder       Liz Rebboah                 NaN
#
#   peer reviewer status (ETA for peer-review)  \
# 0        Wenpin                         Done
# 1        Wenpin                         Done
#
#                                      Marker list URL  \
# 0                                                NaN
# 1  https://drive.google.com/file/d/1IyeaGZxpqO-Qa...
#
#                                      Reference atlas  \
# 0  https://www.synapse.org/#!Synapse:syn21676145/...
# 1  https://www.synapse.org/#!Synapse:syn21676145/...
#
#                               Github link Unnamed: 17
# 0  https://github.com/erebboah/enc4_mouse         NaN
# 1  https://github.com/erebboah/enc4_mouse         NaN

# %%
encode_annotation_df.columns
encode_annotation_df.rename(columns={"Unnamed: 0": "encode_id"}, inplace=True)

# %%
encode_annotation_df.head(2)
# Out:
#      encode_id organism    assay type   assay multiome series  \
# 0  ENCSR322HGX   mouse   10x multiome  scATAC     ENCSR008NTI
# 1          NaN   mouse   10x multiome   snRNA             NaN
#
#   tissue abbreviation                                      tissue name donor  \
# 0                 GAST   B6CastF1 PND14 3x female # 1-3 gastroc muscle   NaN
# 1                 GAST   B6CastF1 PND14 3x female # 1-3 gastroc muscle   NaN
#
#   disease/health status production lab primary analysist secondary analysist  \
# 0               healthy         Snyder       Liz Rebboah                 NaN
# 1               healthy         Snyder       Liz Rebboah                 NaN
#
#   peer reviewer status (ETA for peer-review)  \
# 0        Wenpin                         Done
# 1        Wenpin                         Done
#
#                                      Marker list URL  \
# 0                                                NaN
# 1  https://drive.google.com/file/d/1IyeaGZxpqO-Qa...
#
#                                      Reference atlas  \
# 0  https://www.synapse.org/#!Synapse:syn21676145/...
# 1  https://www.synapse.org/#!Synapse:syn21676145/...
#
#                               Github link Unnamed: 17
# 0  https://github.com/erebboah/enc4_mouse         NaN
# 1  https://github.com/erebboah/enc4_mouse         NaN

# %%
# !pwd
# Out:
# /Users/eilaarich-landkof/Documents/Code_Stanford/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out

# %%
# # load all the files with annotation that were generated
# files_to_update = !ls ./clusters/*/*agAlign_cellTypes_file.tsv
# files_to_update = list(files_to_update)
# files_to_update
# # /Users/eilaarich-landkof/Documents/Code_Stanford/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out

# %%
# load all the files with annotation that were generated
files_to_update = !ls ./clusters/*/*agAlign_cellTypes_file.tsv
files_to_update = list(files_to_update)
files_to_update
# we are looking at the following columns: "encode_id" and "tissue name"
for f in files_to_update[0:1]:
  print(f)
  read_file_to_update_df = read_tsv_file(f)
  print("read_file_to_update_df before adding header")
  print(read_file_to_update_df.head(2))
  position_to_insert = read_file_to_update_df.columns.get_loc("ManualAnnotationLabel") + 1
  read_file_to_update_df = add_empty_column_at_position(read_file_to_update_df, "TissueName", position_to_insert)
#   read_file_to_update_df = add_empty_column(read_file_to_update_df, "TissueName")
  print("read_file_to_update_df after adding header")
  print(read_file_to_update_df.head(2))
  for index, row in read_file_to_update_df.iterrows():
    print("Index:", index)
    print("Row data:", row)
    print("CellClusterID is:",row['CellClusterID'])
    encode_id = row['CellClusterID'].split("_")[0]
    print("encode_id: ",encode_id)
    ManualAnnotationLabel = row['ManualAnnotationLabel']
    print("ManualAnnotationLabel: ",ManualAnnotationLabel)
#     # read the relevant row from ENCODE
    matching_row = encode_annotation_df.loc[encode_annotation_df['encode_id'] == encode_id]
    tissue_name = matching_row.iloc[0]['tissue name']
    print("Tissue Name:", tissue_name)
    read_file_to_update_df.at[index, 'TissueName'] = tissue_name
    print("read_file_to_update_df.at[index, 'TissueName'] is: ",read_file_to_update_df.at[index, 'TissueName'])
    
    
    output_file_path = f  # Replace this with the actual file path you want to save to
    read_file_to_update_df.to_csv(output_file_path, sep='\t', index=False)
    print("File {} was updated".format(f))
    print("-------------------")
# Out:
# ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv
# read_file_to_update_df before adding header
#                                         tagAlignFile         CellClusterID  \
# 0                tagAlign_ENCSR660NEE_Fibroblast.tsv  ENCSR660NEE_Cluster1
# 1  tagAlign_ENCSR660NEE_Vascular_smooth_muscle_ce...  ENCSR660NEE_Cluster2
#
#          ManualAnnotationLabel  nCells MeanRNAUMIsPerCell  \
# 0                   Fibroblast    2444                 ()
# 1  Vascular_smooth_muscle_cell    2867                 ()
#
#    MeanATACFragmentsPerCell
# 0                      6532
# 1                      5463
# read_file_to_update_df after adding header
#                                         tagAlignFile         CellClusterID  \
# 0                tagAlign_ENCSR660NEE_Fibroblast.tsv  ENCSR660NEE_Cluster1
# 1  tagAlign_ENCSR660NEE_Vascular_smooth_muscle_ce...  ENCSR660NEE_Cluster2
#
#          ManualAnnotationLabel TissueName  nCells MeanRNAUMIsPerCell  \
# 0                   Fibroblast               2444                 ()
# 1  Vascular_smooth_muscle_cell               2867                 ()
#
#    MeanATACFragmentsPerCell
# 0                      6532
# 1                      5463
# Index: 0
# Row data: tagAlignFile                tagAlign_ENCSR660NEE_Fibroblast.tsv
# CellClusterID                              ENCSR660NEE_Cluster1
# ManualAnnotationLabel                                Fibroblast
# TissueName
# nCells                                                     2444
# MeanRNAUMIsPerCell                                           ()
# MeanATACFragmentsPerCell                                   6532
# Name: 0, dtype: object
# CellClusterID is: ENCSR660NEE_Cluster1
# encode_id:  ENCSR660NEE
# ManualAnnotationLabel:  Fibroblast
# Tissue Name: esophagus muscularis mucosa
# read_file_to_update_df.at[index, 'TissueName'] is:  esophagus muscularis mucosa
# File ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv was updated
# -------------------
# Index: 1
# Row data: tagAlignFile                tagAlign_ENCSR660NEE_Vascular_smooth_muscle_ce...
# CellClusterID                                            ENCSR660NEE_Cluster2
# ManualAnnotationLabel                             Vascular_smooth_muscle_cell
# TissueName
# nCells                                                                   2867
# MeanRNAUMIsPerCell                                                         ()
# MeanATACFragmentsPerCell                                                 5463
# Name: 1, dtype: object
# CellClusterID is: ENCSR660NEE_Cluster2
# encode_id:  ENCSR660NEE
# ManualAnnotationLabel:  Vascular_smooth_muscle_cell
# Tissue Name: esophagus muscularis mucosa
# read_file_to_update_df.at[index, 'TissueName'] is:  esophagus muscularis mucosa
# File ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv was updated
# -------------------
# Index: 2
# Row data: tagAlignFile                tagAlign_ENCSR660NEE_Mast_cell.tsv
# CellClusterID                             ENCSR660NEE_Cluster3
# ManualAnnotationLabel                                Mast_cell
# TissueName
# nCells                                                     661
# MeanRNAUMIsPerCell                                          ()
# MeanATACFragmentsPerCell                                  4114
# Name: 2, dtype: object
# CellClusterID is: ENCSR660NEE_Cluster3
# encode_id:  ENCSR660NEE
# ManualAnnotationLabel:  Mast_cell
# Tissue Name: esophagus muscularis mucosa
# read_file_to_update_df.at[index, 'TissueName'] is:  esophagus muscularis mucosa
# File ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv was updated
# -------------------
# Index: 3
# Row data: tagAlignFile                tagAlign_ENCSR660NEE_Schwann_cell.tsv
# CellClusterID                                ENCSR660NEE_Cluster4
# ManualAnnotationLabel                                Schwann_cell
# TissueName
# nCells                                                        578
# MeanRNAUMIsPerCell                                             ()
# MeanATACFragmentsPerCell                                     5700
# Name: 3, dtype: object
# CellClusterID is: ENCSR660NEE_Cluster4
# encode_id:  ENCSR660NEE
# ManualAnnotationLabel:  Schwann_cell
# Tissue Name: esophagus muscularis mucosa
# read_file_to_update_df.at[index, 'TissueName'] is:  esophagus muscularis mucosa
# File ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv was updated
# -------------------
# Index: 4
# Row data: tagAlignFile                tagAlign_ENCSR660NEE_Endothelial_cell.tsv
# CellClusterID                                    ENCSR660NEE_Cluster5
# ManualAnnotationLabel                                Endothelial_cell
# TissueName
# nCells                                                            376
# MeanRNAUMIsPerCell                                                 ()
# MeanATACFragmentsPerCell                                         4340
# Name: 4, dtype: object
# CellClusterID is: ENCSR660NEE_Cluster5
# encode_id:  ENCSR660NEE
# ManualAnnotationLabel:  Endothelial_cell
# Tissue Name: esophagus muscularis mucosa
# read_file_to_update_df.at[index, 'TissueName'] is:  esophagus muscularis mucosa
# File ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv was updated
# -------------------
# Index: 5
# Row data: tagAlignFile                tagAlign_ENCSR660NEE_Macrophage.tsv
# CellClusterID                              ENCSR660NEE_Cluster6
# ManualAnnotationLabel                                Macrophage
# TissueName
# nCells                                                      607
# MeanRNAUMIsPerCell                                           ()
# MeanATACFragmentsPerCell                                   4934
# Name: 5, dtype: object
# CellClusterID is: ENCSR660NEE_Cluster6
# encode_id:  ENCSR660NEE
# ManualAnnotationLabel:  Macrophage
# Tissue Name: esophagus muscularis mucosa
# read_file_to_update_df.at[index, 'TissueName'] is:  esophagus muscularis mucosa
# File ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv was updated
# -------------------
# Index: 6
# Row data: tagAlignFile                tagAlign_ENCSR660NEE_T_lymphocyte.tsv
# CellClusterID                                ENCSR660NEE_Cluster7
# ManualAnnotationLabel                                T_lymphocyte
# TissueName
# nCells                                                        416
# MeanRNAUMIsPerCell                                             ()
# MeanATACFragmentsPerCell                                     3741
# Name: 6, dtype: object
# CellClusterID is: ENCSR660NEE_Cluster7
# encode_id:  ENCSR660NEE
# ManualAnnotationLabel:  T_lymphocyte
# Tissue Name: esophagus muscularis mucosa
# read_file_to_update_df.at[index, 'TissueName'] is:  esophagus muscularis mucosa
# File ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv was updated
# -------------------
# Index: 7
# Row data: tagAlignFile                tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv
# CellClusterID                                      ENCSR660NEE_Cluster8
# ManualAnnotationLabel                                Smooth_muscle_cell
# TissueName
# nCells                                                              534
# MeanRNAUMIsPerCell                                                   ()
# MeanATACFragmentsPerCell                                           5779
# Name: 7, dtype: object
# CellClusterID is: ENCSR660NEE_Cluster8
# encode_id:  ENCSR660NEE
# ManualAnnotationLabel:  Smooth_muscle_cell
# Tissue Name: esophagus muscularis mucosa
# read_file_to_update_df.at[index, 'TissueName'] is:  esophagus muscularis mucosa
# File ./clusters/cluster0/ENCSR660NEE_stats_tagAlign_cellTypes_file.tsv was updated
# -------------------

# %%
read_file_to_update_df
# Out:
#                                         tagAlignFile         CellClusterID  \
# 0                tagAlign_ENCSR660NEE_Fibroblast.tsv  ENCSR660NEE_Cluster1
# 1  tagAlign_ENCSR660NEE_Vascular_smooth_muscle_ce...  ENCSR660NEE_Cluster2
# 2                 tagAlign_ENCSR660NEE_Mast_cell.tsv  ENCSR660NEE_Cluster3
# 3              tagAlign_ENCSR660NEE_Schwann_cell.tsv  ENCSR660NEE_Cluster4
# 4          tagAlign_ENCSR660NEE_Endothelial_cell.tsv  ENCSR660NEE_Cluster5
# 5                tagAlign_ENCSR660NEE_Macrophage.tsv  ENCSR660NEE_Cluster6
# 6              tagAlign_ENCSR660NEE_T_lymphocyte.tsv  ENCSR660NEE_Cluster7
# 7        tagAlign_ENCSR660NEE_Smooth_muscle_cell.tsv  ENCSR660NEE_Cluster8
#
#          ManualAnnotationLabel                   TissueName  nCells  \
# 0                   Fibroblast  esophagus muscularis mucosa    2444
# 1  Vascular_smooth_muscle_cell  esophagus muscularis mucosa    2867
# 2                    Mast_cell  esophagus muscularis mucosa     661
# 3                 Schwann_cell  esophagus muscularis mucosa     578
# 4             Endothelial_cell  esophagus muscularis mucosa     376
# 5                   Macrophage  esophagus muscularis mucosa     607
# 6                 T_lymphocyte  esophagus muscularis mucosa     416
# 7           Smooth_muscle_cell  esophagus muscularis mucosa     534
#
#   MeanRNAUMIsPerCell  MeanATACFragmentsPerCell
# 0                 ()                      6532
# 1                 ()                      5463
# 2                 ()                      4114
# 3                 ()                      5700
# 4                 ()                      4340
# 5                 ()                      4934
# 6                 ()                      3741
# 7                 ()                      5779
