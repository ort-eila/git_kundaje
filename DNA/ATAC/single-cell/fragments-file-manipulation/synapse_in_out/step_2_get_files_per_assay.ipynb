# %% [markdown]
# install synapse client
# - conda install -c bioconda synapseclient
# if import fires error, install
# - pip install synapseclient

# %%
import os
# https://python-docs.synapse.org/build/html/Credentials.html#use-synapseconfig
os.environ['SYNAPSE_AUTH_TOKEN']='eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..DXooWvrEDivGIv3tHTdXP6EGgsCLHMcoV1nqdTRv1_2_nThWYAvheuBABhkN1OZic8U0713yGA-QIp4wCAHNSa3zOibDvhSJ58pxgtGVuuUc4nzD5hF5r4vVwH__TcfCAAjVQeCWGizC8b_4CkhoCBuT-yThtBOhok8fI_vn1ut3E6ZgTutSGW4jgSww8r404Wwf3I_2zfQqrg8Sjab9H6wZQg6Kn7L1vZUu2MNZyw4QDerOledKCz1HXFFeKwwbuVFcL-4evALSN0i-IQCevWtey8S-ag9eKytwYa0hWnHd7CzS3SYos3B5HAsXrZ7-c057mpT3p0XGtRygpXmiBQ'

# %%
import synapseclient
import synapseutils
import os
import csv
import pandas as pd
token = os.environ.get('SYNAPSE_AUTH_TOKEN')

import synapseclient
syn = synapseclient.login(authToken=token)
# Out:
# Welcome, eila!

# %%
#TOOD
# Define the path and name of the TSV file. Take from step1
tsv_file_path = "syn52118179_synpase_files.tsv"
local_path_to_download = os.path.join(os.getcwd(),"fragment_files")
os.makedirs(local_path_to_download,exist_ok=True)

# %%
tsv_dataframe = pd.read_csv(tsv_file_path, sep="\t")

print(tsv_dataframe.head(2))
# Out:
#     Dataset Id                                      File Name      File ID  \
# 0  syn52118179  ENCSR023FME.atac.filter.fragments.hg38.tsv.gz  syn52119935
# 1  syn52118179  ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz  syn52119924
#
#    File Version
# 0             1
# 1             1

# %%
local_fragment_file_path=list()
for index, row in tsv_dataframe.iterrows():
    print("index is {}".format(index))
    print("row is {}".format(row))
    # if index != 0:
    #     continue # debug only
    file_id = row["File ID"]
    file_name = row["File Name"]
    dataset_id = row["Dataset Id"]
    local_fragment_file_path = os.path.join(local_path_to_download,"{}_{}_{}".format(dataset_id,file_id,file_name))
    if os.path.exists(local_fragment_file_path) == False:
        local_fragment_file_synHandle = syn.get(entity=file_id,downloadLocation=local_fragment_file_path) 
        print('local_fragment_file_synHandle is {}'.format(local_fragment_file_synHandle))
        full_local_fragment_file_synHandle = local_fragment_file_synHandle.path
        print('full_local_fragment_file_synHandle is {}'.format(full_local_fragment_file_synHandle))
    else:
        print("local_fragment_file_path exists. {} ".format(local_fragment_file_path))
# print(local_fragment_file_path[0:4])
# print(len(local_fragment_file_path))
# Out:
# index is 0
# row is Dataset Id                                        syn52118179
# File Name       ENCSR023FME.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119935
# File Version                                                1
# Name: 0, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119935_ENCSR023FME.atac.filter.fragments.hg38.tsv.gz
# index is 1
# row is Dataset Id                                        syn52118179
# File Name       ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119924
# File Version                                                1
# Name: 1, dtype: object
# local_fragment_file_synHandle is File: ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz (syn52119924)
#   md5=55ae569137b56cf95f71b55c025de98f
#   fileSize=1613764651
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119924_ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119924_ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz/ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:03:45.601Z
#   dataFileHandleId=127201244
#   etag=8f7f1b63-6202-4e92-8455-394c434208e0
#   id=syn52119924
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:03:45.856Z
#   name=ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['Va5WkTe1bPlfcbVcAl3pjw==']
#   subpool=['ENCSR052DKH']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119924_ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz/ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz
# index is 2
# row is Dataset Id                                        syn52118179
# File Name       ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119948
# File Version                                                1
# Name: 2, dtype: object
# local_fragment_file_synHandle is File: ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz (syn52119948)
#   md5=fba4bf78ab6c288de6ab08121f8d96e2
#   fileSize=520951777
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119948_ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119948_ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz/ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:06:14.498Z
#   dataFileHandleId=127201286
#   etag=6fa7cfc0-13ab-43c3-99e2-da642f4ca4cb
#   id=syn52119948
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:06:14.745Z
#   name=ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['+6S/eKtsKI3mqwgSH42W4g==']
#   subpool=['ENCSR181XXQ']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119948_ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz/ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz
# index is 3
# row is Dataset Id                                        syn52118179
# File Name       ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119971
# File Version                                                1
# Name: 3, dtype: object
# local_fragment_file_synHandle is File: ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz (syn52119971)
#   md5=afbb8d4b200dfa997b2e4616a5d5d9ff
#   fileSize=699315566
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119971_ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119971_ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz/ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:08:11.903Z
#   dataFileHandleId=127201323
#   etag=898a7c85-41a4-4d6c-a5ee-cf15c00c3225
#   id=syn52119971
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:08:12.174Z
#   name=ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['r7uNSyAN+pl7LkYWpdXZ/w==']
#   subpool=['ENCSR205TUH']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119971_ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz/ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz
# index is 4
# row is Dataset Id                                        syn52118179
# File Name       ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119923
# File Version                                                1
# Name: 4, dtype: object
# local_fragment_file_synHandle is File: ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz (syn52119923)
#   md5=ec8a23ec5f2af607a34b93dd6a1b4e42
#   fileSize=441882388
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119923_ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119923_ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz/ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:03:21.624Z
#   dataFileHandleId=127201242
#   etag=d896665f-caab-498c-9df4-7436235743a2
#   id=syn52119923
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:03:21.920Z
#   name=ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['7Ioj7F8q9gejS5PdahtOQg==']
#   subpool=['ENCSR261TQO']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119923_ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz/ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
# index is 5
# row is Dataset Id                                        syn52118179
# File Name       ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119968
# File Version                                                1
# Name: 5, dtype: object
# local_fragment_file_synHandle is File: ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz (syn52119968)
#   md5=1ac13d67c810cbafb1a97100b549d056
#   fileSize=804867376
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119968_ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119968_ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz/ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:07:41.468Z
#   dataFileHandleId=127201319
#   etag=8c32a220-b10a-40f5-8d96-e12c67a4b8be
#   id=syn52119968
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:07:41.727Z
#   name=ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['GsE9Z8gQy6+xqXEAtUnQVg==']
#   subpool=['ENCSR302CMX']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119968_ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz/ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz
# index is 6
# row is Dataset Id                                        syn52118179
# File Name       ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119958
# File Version                                                1
# Name: 6, dtype: object
# local_fragment_file_synHandle is File: ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz (syn52119958)
#   md5=04c60090e15cd423b8d1621b3d09394d
#   fileSize=737463487
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119958_ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119958_ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz/ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:06:47.141Z
#   dataFileHandleId=127201302
#   etag=46dbed22-0150-44a7-9fdc-de8a4b31264a
#   id=syn52119958
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:06:47.427Z
#   name=ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['BMYAkOFc1CO40WIbPQk5TQ==']
#   subpool=['ENCSR367GKP']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119958_ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz/ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz
# index is 7
# row is Dataset Id                                        syn52118179
# File Name       ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119960
# File Version                                                1
# Name: 7, dtype: object
# local_fragment_file_synHandle is File: ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz (syn52119960)
#   md5=1bfe065b4fe91d40f2fa668caf03f0a3
#   fileSize=782917795
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119960_ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119960_ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz/ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:06:58.834Z
#   dataFileHandleId=127201305
#   etag=48302b2c-0f4d-43cb-9d44-87bb53eb7069
#   id=syn52119960
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:06:59.097Z
#   name=ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['G/4GW0/pHUDy+maMrwPwow==']
#   subpool=['ENCSR397LYX']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119960_ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz/ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz
# index is 8
# row is Dataset Id                                        syn52118179
# File Name       ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119922
# File Version                                                1
# Name: 8, dtype: object
# local_fragment_file_synHandle is File: ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz (syn52119922)
#   md5=a5361a053258182b95da05ac8c7dc0b9
#   fileSize=736633552
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119922_ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119922_ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz/ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:03:14.274Z
#   dataFileHandleId=127201240
#   etag=f712c1c4-d222-4fa4-8063-642b8aa4e5a2
#   id=syn52119922
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:03:14.553Z
#   name=ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['pTYaBTJYGCuV2gWsjH3AuQ==']
#   subpool=['ENCSR411MLR']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119922_ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz/ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz
# index is 9
# row is Dataset Id                                        syn52118179
# File Name       ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119936
# File Version                                                1
# Name: 9, dtype: object
# local_fragment_file_synHandle is File: ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz (syn52119936)
#   md5=690573b9cee4a90a36e3937876b1e676
#   fileSize=832782393
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119936_ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119936_ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz/ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:04:48.551Z
#   dataFileHandleId=127201264
#   etag=7334806d-b06a-4367-9472-151af9035e6b
#   id=syn52119936
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:04:48.801Z
#   name=ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['aQVzuc7kqQo245N4drHmdg==']
#   subpool=['ENCSR453TVZ']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119936_ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz/ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz
# index is 10
# row is Dataset Id                                        syn52118179
# File Name       ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119985
# File Version                                                1
# Name: 10, dtype: object
# local_fragment_file_synHandle is File: ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz (syn52119985)
#   md5=a9daf102e3e8ee3a2f18631268113740
#   fileSize=1507975957
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119985_ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119985_ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz/ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:09:02.807Z
#   dataFileHandleId=127201346
#   etag=44ed2d63-f869-4e68-b7e6-e28c0fba44a6
#   id=syn52119985
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:09:03.130Z
#   name=ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['qdrxAuPo7jovGGMSaBE3QA==']
#   subpool=['ENCSR455CVZ']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119985_ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz/ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz
# index is 11
# row is Dataset Id                                        syn52118179
# File Name       ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119946
# File Version                                                1
# Name: 11, dtype: object
# local_fragment_file_synHandle is File: ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz (syn52119946)
#   md5=aac2c80c102a8f15985d36b4ed4136b7
#   fileSize=539014391
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119946_ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119946_ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz/ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:05:43.983Z
#   dataFileHandleId=127201282
#   etag=1dc8f6b5-54b6-4d23-baa3-cd2359bef676
#   id=syn52119946
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:05:44.260Z
#   name=ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['qsLIDBAqjxWYXTa07UE2tw==']
#   subpool=['ENCSR474TGL']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119946_ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz/ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz
# index is 12
# row is Dataset Id                                        syn52118179
# File Name       ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119983
# File Version                                                1
# Name: 12, dtype: object
# local_fragment_file_synHandle is File: ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz (syn52119983)
#   md5=a08b57c204c8943d4574add50ad3df8f
#   fileSize=671747054
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119983_ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119983_ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz/ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:08:39.186Z
#   dataFileHandleId=127201343
#   etag=254a1021-2d9e-4a43-a54a-141cf7495945
#   id=syn52119983
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:08:39.434Z
#   name=ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['oItXwgTIlD1FdK3VCtPfjw==']
#   subpool=['ENCSR506YMX']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119983_ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz/ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz
# index is 13
# row is Dataset Id                                        syn52118179
# File Name       ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119947
# File Version                                                1
# Name: 13, dtype: object
# local_fragment_file_synHandle is File: ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz (syn52119947)
#   md5=d457333fee3fef7a72184b9858e23b4b
#   fileSize=1052514627
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119947_ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119947_ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz/ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:06:05.622Z
#   dataFileHandleId=127201284
#   etag=3568ebf4-5953-49f2-9c40-03c1da2ae2c4
#   id=syn52119947
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:06:05.897Z
#   name=ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['1FczP+4/73pyGEuYWOI7Sw==']
#   subpool=['ENCSR538FPK']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119947_ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz/ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz
# index is 14
# row is Dataset Id                                        syn52118179
# File Name       ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119934
# File Version                                                1
# Name: 14, dtype: object
# local_fragment_file_synHandle is File: ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz (syn52119934)
#   md5=d9b1ed0cadc2d00e33d866fe4b68a57f
#   fileSize=939507428
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119934_ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119934_ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz/ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:04:23.379Z
#   dataFileHandleId=127201260
#   etag=13b5dd46-55d9-443c-92ae-9b3863be4da9
#   id=syn52119934
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:04:23.649Z
#   name=ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['2bHtDK3C0A4z2Gb+S2ilfw==']
#   subpool=['ENCSR660NEE']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119934_ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz/ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz
# index is 15
# row is Dataset Id                                        syn52118179
# File Name       ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119982
# File Version                                                1
# Name: 15, dtype: object
# local_fragment_file_synHandle is File: ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz (syn52119982)
#   md5=8e410b34d41bc9b8787409a87a551267
#   fileSize=484281368
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119982_ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119982_ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz/ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:08:27.237Z
#   dataFileHandleId=127201341
#   etag=0bae740e-9c40-452c-85e0-901d608ecfda
#   id=syn52119982
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:08:27.522Z
#   name=ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['jkELNNQbybh4dAmoelUSZw==']
#   subpool=['ENCSR718WGE']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119982_ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz/ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz
# index is 16
# row is Dataset Id                                        syn52118179
# File Name       ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119951
# File Version                                                1
# Name: 16, dtype: object
# local_fragment_file_synHandle is File: ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz (syn52119951)
#   md5=b57d176cf47fc946973f6f8b27b59f4e
#   fileSize=673675709
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119951_ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119951_ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz/ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:06:26.212Z
#   dataFileHandleId=127201290
#   etag=d64e0619-496c-4fda-b4f4-e6ad7842faa5
#   id=syn52119951
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:06:26.502Z
#   name=ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['tX0XbPR/yUaXP2+LJ7WfTg==']
#   subpool=['ENCSR776EOI']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119951_ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz/ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz
# index is 17
# row is Dataset Id                                        syn52118179
# File Name       ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119967
# File Version                                                1
# Name: 17, dtype: object
# local_fragment_file_synHandle is File: ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz (syn52119967)
#   md5=ab22796e3a2a48326017731e30d561a7
#   fileSize=722054929
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119967_ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119967_ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz/ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:07:26.483Z
#   dataFileHandleId=127201317
#   etag=33f96334-f26c-4487-9dca-4bbba12c96b3
#   id=syn52119967
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:07:26.746Z
#   name=ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['qyJ5bjoqSDJgF3MeMNVhpw==']
#   subpool=['ENCSR796RXX']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119967_ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz/ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz
# index is 18
# row is Dataset Id                                        syn52118179
# File Name       ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119970
# File Version                                                1
# Name: 18, dtype: object
# local_fragment_file_synHandle is File: ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz (syn52119970)
#   md5=4509785fcf31a8993237c82db9fda434
#   fileSize=1292936063
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119970_ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119970_ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz/ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:08:03.281Z
#   dataFileHandleId=127201321
#   etag=fe19249c-6a86-458e-b264-3b180da8ec7e
#   id=syn52119970
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:08:03.541Z
#   name=ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['RQl4X88xqJkyN8gtuf2kNA==']
#   subpool=['ENCSR822GXQ']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119970_ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz/ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz
# index is 19
# row is Dataset Id                                        syn52118179
# File Name       ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119927
# File Version                                                1
# Name: 19, dtype: object
# local_fragment_file_synHandle is File: ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz (syn52119927)
#   md5=20582ff82698e2babfbdc60a993f806b
#   fileSize=751313419
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119927_ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119927_ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz/ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:03:57.724Z
#   dataFileHandleId=127201248
#   etag=82b0faac-7774-41db-ba21-6c8fd5bfc94a
#   id=syn52119927
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:03:58.006Z
#   name=ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['IFgv+CaY4rq/vcYKmT+Aaw==']
#   subpool=['ENCSR845QFX']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119927_ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz/ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz
# index is 20
# row is Dataset Id                                        syn52118179
# File Name       ENCSR848EID.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119956
# File Version                                                1
# Name: 20, dtype: object
# local_fragment_file_synHandle is File: ENCSR848EID.atac.filter.fragments.hg38.tsv.gz (syn52119956)
#   md5=b169ffb31553e55a7b294d22c85f1d52
#   fileSize=201925478
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119956_ENCSR848EID.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR848EID.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119956_ENCSR848EID.atac.filter.fragments.hg38.tsv.gz/ENCSR848EID.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:06:33.184Z
#   dataFileHandleId=127201299
#   etag=0349a887-5570-4576-b66b-daba06445a66
#   id=syn52119956
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:06:33.427Z
#   name=ENCSR848EID.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['sWn/sxVT5Vp7KU0iyF8dUg==']
#   subpool=['ENCSR848EID']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119956_ENCSR848EID.atac.filter.fragments.hg38.tsv.gz/ENCSR848EID.atac.filter.fragments.hg38.tsv.gz
# index is 21
# row is Dataset Id                                        syn52118179
# File Name       ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119939
# File Version                                                1
# Name: 21, dtype: object
# local_fragment_file_synHandle is File: ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz (syn52119939)
#   md5=3f4c7ea728ee4aaf3204ccbaaa17dcab
#   fileSize=1611510550
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119939_ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119939_ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz/ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:05:20.583Z
#   dataFileHandleId=127201270
#   etag=d5f2a832-5761-41c0-a83b-27a1b39d1a7f
#   id=syn52119939
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:05:20.844Z
#   name=ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['P0x+pyjuSq8yBMy6qhfcqw==']
#   subpool=['ENCSR868ZEI']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119939_ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz/ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz

# %%
# !ls -lt /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/
# Out:
# total 0
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:19 syn52118179_syn52119939_ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:18 syn52118179_syn52119956_ENCSR848EID.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:18 syn52118179_syn52119927_ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:17 syn52118179_syn52119970_ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:16 syn52118179_syn52119967_ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:16 syn52118179_syn52119951_ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:15 syn52118179_syn52119982_ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:15 syn52118179_syn52119934_ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:14 syn52118179_syn52119947_ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:13 syn52118179_syn52119983_ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:12 syn52118179_syn52119946_ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:12 syn52118179_syn52119985_ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:11 syn52118179_syn52119936_ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:10 syn52118179_syn52119922_ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:09 syn52118179_syn52119960_ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:08 syn52118179_syn52119958_ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:07 syn52118179_syn52119968_ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:06 syn52118179_syn52119923_ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:05 syn52118179_syn52119971_ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:04 syn52118179_syn52119948_ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:04 syn52118179_syn52119924_ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz
# drwxr-xr-x  3 eilaarich-landkof-stanford  staff  96 Jul 25 22:02 syn52118179_syn52119935_ENCSR023FME.atac.filter.fragments.hg38.tsv.gz
