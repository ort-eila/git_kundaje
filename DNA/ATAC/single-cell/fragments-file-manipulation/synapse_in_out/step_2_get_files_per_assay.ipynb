# %% [markdown]
# install synapse client
# - conda install -c bioconda synapseclient
# if import fires error, install
# - pip install synapseclient

# %%
import os
# https://python-docs.synapse.org/build/html/Credentials.html#use-synapseconfig
os.environ['SYNAPSE_AUTH_TOKEN']='eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..DXooWvrEDivGIv3tHTdXP6EGgsCLHMcoV1nqdTRv1_2_nThWYAvheuBABhkN1OZic8U0713yGA-QIp4wCAHNSa3zOibDvhSJ58pxgtGVuuUc4nzD5hF5r4vVwH__TcfCAAjVQeCWGizC8b_4CkhoCBuT-yThtBOhok8fI_vn1ut3E6ZgTutSGW4jgSww8r404Wwf3I_2zfQqrg8Sjab9H6wZQg6Kn7L1vZUu2MNZyw4QDerOledKCz1HXFFeKwwbuVFcL-4evALSN0i-IQCevWtey8S-ag9eKytwYa0hWnHd7CzS3SYos3B5HAsXrZ7-c057mpT3p0XGtRygpXmiBQ'

# %%
import synapseclient
import synapseutils
import os
import csv
import pandas as pd
token = os.environ.get('SYNAPSE_AUTH_TOKEN')

import synapseclient
syn = synapseclient.login(authToken=token)
# Out:
# Welcome, eila!

# %%
#TOOD
# Define the path and name of the TSV file. Take from step1
tsv_file_path = "syn52118179_synpase_files.tsv"
local_path_to_download = os.path.join(os.getcwd(),"fragment_files")
os.makedirs(local_path_to_download,exist_ok=True)

# %%
tsv_dataframe = pd.read_csv(tsv_file_path, sep="\t")

print(tsv_dataframe.head(2))
# Out:
#     Dataset Id                                      File Name      File ID  \
# 0  syn52118179  ENCSR023FME.atac.filter.fragments.hg38.tsv.gz  syn52119935
# 1  syn52118179  ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz  syn52119924
#
#    File Version
# 0             1
# 1             1

# %%
local_fragment_file_path=list()
for index, row in tsv_dataframe.iterrows():
    print("index is {}".format(index))
    print("row is {}".format(row))
    # if index != 0:
    #     continue # debug only
    file_id = row["File ID"]
    file_name = row["File Name"]
    dataset_id = row["Dataset Id"]
    local_fragment_file_path = os.path.join(local_path_to_download,"{}_{}_{}".format(dataset_id,file_id,file_name))
    if os.path.exists(local_fragment_file_path) == False:
        local_fragment_file_synHandle = syn.get(entity=file_id,downloadLocation=local_fragment_file_path) 
        print('local_fragment_file_synHandle is {}'.format(local_fragment_file_synHandle))
        full_local_fragment_file_synHandle = local_fragment_file_synHandle.path
        print('full_local_fragment_file_synHandle is {}'.format(full_local_fragment_file_synHandle))
    else:
        print("local_fragment_file_path exists. {} ".format(local_fragment_file_path))
# print(local_fragment_file_path[0:4])
# print(len(local_fragment_file_path))
# Out:
# index is 0
# row is Dataset Id                                        syn52118179
# File Name       ENCSR023FME.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119935
# File Version                                                1
# Name: 0, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119935_ENCSR023FME.atac.filter.fragments.hg38.tsv.gz
# index is 1
# row is Dataset Id                                        syn52118179
# File Name       ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119924
# File Version                                                1
# Name: 1, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119924_ENCSR052DKH.atac.filter.fragments.hg38.tsv.gz
# index is 2
# row is Dataset Id                                        syn52118179
# File Name       ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119948
# File Version                                                1
# Name: 2, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119948_ENCSR181XXQ.atac.filter.fragments.hg38.tsv.gz
# index is 3
# row is Dataset Id                                        syn52118179
# File Name       ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119971
# File Version                                                1
# Name: 3, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119971_ENCSR205TUH.atac.filter.fragments.hg38.tsv.gz
# index is 4
# row is Dataset Id                                        syn52118179
# File Name       ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119923
# File Version                                                1
# Name: 4, dtype: object
# local_fragment_file_synHandle is File: ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz (syn52119923)
#   md5=ec8a23ec5f2af607a34b93dd6a1b4e42
#   fileSize=441882388
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119923_ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
#   files=['ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz']
#   path=/Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119923_ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz/ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:03:21.624Z
#   dataFileHandleId=127201242
#   etag=d896665f-caab-498c-9df4-7436235743a2
#   id=syn52119923
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:03:21.920Z
#   name=ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118179
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['7Ioj7F8q9gejS5PdahtOQg==']
#   subpool=['ENCSR261TQO']
#
# full_local_fragment_file_synHandle is /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119923_ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz/ENCSR261TQO.atac.filter.fragments.hg38.tsv.gz
# index is 5
# row is Dataset Id                                        syn52118179
# File Name       ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119968
# File Version                                                1
# Name: 5, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119968_ENCSR302CMX.atac.filter.fragments.hg38.tsv.gz
# index is 6
# row is Dataset Id                                        syn52118179
# File Name       ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119958
# File Version                                                1
# Name: 6, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119958_ENCSR367GKP.atac.filter.fragments.hg38.tsv.gz
# index is 7
# row is Dataset Id                                        syn52118179
# File Name       ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119960
# File Version                                                1
# Name: 7, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119960_ENCSR397LYX.atac.filter.fragments.hg38.tsv.gz
# index is 8
# row is Dataset Id                                        syn52118179
# File Name       ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119922
# File Version                                                1
# Name: 8, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119922_ENCSR411MLR.atac.filter.fragments.hg38.tsv.gz
# index is 9
# row is Dataset Id                                        syn52118179
# File Name       ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119936
# File Version                                                1
# Name: 9, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119936_ENCSR453TVZ.atac.filter.fragments.hg38.tsv.gz
# index is 10
# row is Dataset Id                                        syn52118179
# File Name       ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119985
# File Version                                                1
# Name: 10, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119985_ENCSR455CVZ.atac.filter.fragments.hg38.tsv.gz
# index is 11
# row is Dataset Id                                        syn52118179
# File Name       ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119946
# File Version                                                1
# Name: 11, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119946_ENCSR474TGL.atac.filter.fragments.hg38.tsv.gz
# index is 12
# row is Dataset Id                                        syn52118179
# File Name       ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119983
# File Version                                                1
# Name: 12, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119983_ENCSR506YMX.atac.filter.fragments.hg38.tsv.gz
# index is 13
# row is Dataset Id                                        syn52118179
# File Name       ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119947
# File Version                                                1
# Name: 13, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119947_ENCSR538FPK.atac.filter.fragments.hg38.tsv.gz
# index is 14
# row is Dataset Id                                        syn52118179
# File Name       ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119934
# File Version                                                1
# Name: 14, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119934_ENCSR660NEE.atac.filter.fragments.hg38.tsv.gz
# index is 15
# row is Dataset Id                                        syn52118179
# File Name       ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119982
# File Version                                                1
# Name: 15, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119982_ENCSR718WGE.atac.filter.fragments.hg38.tsv.gz
# index is 16
# row is Dataset Id                                        syn52118179
# File Name       ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119951
# File Version                                                1
# Name: 16, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119951_ENCSR776EOI.atac.filter.fragments.hg38.tsv.gz
# index is 17
# row is Dataset Id                                        syn52118179
# File Name       ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119967
# File Version                                                1
# Name: 17, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119967_ENCSR796RXX.atac.filter.fragments.hg38.tsv.gz
# index is 18
# row is Dataset Id                                        syn52118179
# File Name       ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119970
# File Version                                                1
# Name: 18, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119970_ENCSR822GXQ.atac.filter.fragments.hg38.tsv.gz
# index is 19
# row is Dataset Id                                        syn52118179
# File Name       ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119927
# File Version                                                1
# Name: 19, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119927_ENCSR845QFX.atac.filter.fragments.hg38.tsv.gz
# index is 20
# row is Dataset Id                                        syn52118179
# File Name       ENCSR848EID.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119956
# File Version                                                1
# Name: 20, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119956_ENCSR848EID.atac.filter.fragments.hg38.tsv.gz
# index is 21
# row is Dataset Id                                        syn52118179
# File Name       ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz
# File ID                                           syn52119939
# File Version                                                1
# Name: 21, dtype: object
# local_fragment_file_path exists. /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/syn52118179_syn52119939_ENCSR868ZEI.atac.filter.fragments.hg38.tsv.gz

# %%
# !ls -lt /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/
